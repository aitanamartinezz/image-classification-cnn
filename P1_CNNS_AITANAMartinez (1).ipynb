# %% [markdown]
# # Deep Learning: Practice 1 CNNs
# ## Aitana Martínez Rey

# %% [markdown]
# ### Part 1: Custom CNNs

# %% [markdown]
# ### 1.1 Exploring the dataset

# %% [markdown]
# The CIFAR-100 dataset is a collection of 60,000 color images (32x32 pixels) divided into 100 classes, with 600 images per class.
# Each image belongs to one of 20 superclasses, grouping similar categories together. We will try to classify these superclasses.
# The dataset is split into 50,000 training images and 10,000 test images.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras import regularizers
import tensorflow as tf
from tensorflow import keras
from keras.utils import to_categorical
from keras import models
from keras import layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split

# %%
# Import dataset and load dataset
## In this case we are user label_mode = 'coarse', because we are going to try to classify in the 20 different superclasses
(train_x, train_y), (test_x, test_y) = keras.datasets.cifar100.load_data(label_mode="coarse")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 ━━━━━━━━━━━━━━━━━━━━ 14s 0us/step

# %%
# Summarize dataset shapes
print("train_x shape:", train_x.shape)
print("train_y shape:", train_y.shape)
print("test_x shape:", test_x.shape)
print("test_y shape:", test_y.shape)
# Out:
# train_x shape: (50000, 32, 32, 3)
# train_y shape: (50000, 1)
# test_x shape: (10000, 32, 32, 3)
# test_y shape: (10000, 1)

# %%
# Data format
print(type(train_x))
print(type(train_y))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
# We are going to map the label names to the class
coarse_label_names = [
    "aquatic mammals", "fish", "flowers", "food containers", "fruit and vegetables",
    "household electrical devices", "household furniture", "insects", "large carnivores",
    "large man-made outdoor things", "large natural outdoor scenes", "large omnivores and herbivores",
    "medium-sized mammals", "non-insect invertebrates", "people", "reptiles",
    "small mammals", "trees", "vehicles 1", "vehicles 2"
]

coarse_label_dict = {i: name for i, name in enumerate(coarse_label_names)}

# For example class 4 now belongs to fruit and vegetables superclass
label = 4
print(f"Class number: {label}, Superclass: {coarse_label_dict[label]}")
# Out:
# Class number: 4, Superclass: fruit and vegetables

# %% [markdown]
# We can show randomly some images in the CIFAR-100 dataset as an example

# %%
plt.figure(figsize=(10, 10))
for i in range(16):
    rand_num = np.random.randint(0, len(train_x))
    plt.subplot(4, 4, i+1)
    plt.imshow(train_x[rand_num])
    plt.title(coarse_label_dict[train_y[rand_num][0]], fontsize=10)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.2 Data preprocessing

# %%
# First of all we will reshape images
train_x = train_x.reshape(-1, 32,32,3)
test_x = test_x.reshape(-1, 32,32,3)

# %%
# Normalize the image data to a range of 0 to 1
train_x = train_x.astype('float32') / 255.0
test_x = test_x.astype('float32') / 255.0
print('train: x=%s, y=%s' % (train_x.shape, train_y.shape))
print('test: x=%s, y=%s' % (test_x.shape, test_y.shape))
# Out:
# train: x=(50000, 32, 32, 3), y=(50000, 1)
# test: x=(10000, 32, 32, 3), y=(10000, 1)

# %%
# Convert class labels to one-hot encoding
train_y = to_categorical(train_y)
test_y = to_categorical(test_y)
# Print the shapes of the preprocessed data
print("Training data shape:", train_x.shape)
print("Training labels shape:", train_y.shape)
print("Testing data shape:", test_x.shape)
print("Testing labels shape:", test_y.shape)
# Out:
# Training data shape: (50000, 32, 32, 3)
# Training labels shape: (50000, 20)
# Testing data shape: (10000, 32, 32, 3)
# Testing labels shape: (10000, 20)

# %% [markdown]
# Now we should create a validation dataset from the training dataset for hyperparameter tuning

# %%
train_x, val_x, train_y, val_y = train_test_split(train_x, train_y, test_size=0.2, random_state=42)

# We repeat the preprocessing process for this new dataset
val_x = val_x.reshape(-1, 32,32,3)
val_x = val_x.astype('float32') / 255.0
train_x = train_x.reshape(-1, 32,32,3)
test_x = test_x.reshape(-1, 32,32,3)
# Normalize the image data to a range of 0 to 1
train_x = train_x.astype('float32') / 255.0
test_x = test_x.astype('float32') / 255.0


# Show dimensions
print(f"Training dimensions: {train_x.shape}, {train_y.shape}")
print(f"Validation dimensions: {val_x.shape}, {val_y.shape}")
# Out:
# Training dimensions: (40000, 32, 32, 3), (40000, 20)
# Validation dimensions: (10000, 32, 32, 3), (10000, 20)

# %% [markdown]
# ## 1.3 Model approaches

# %% [markdown]
# As we are not aware of the best hyperparameters for this specific dataset, I'm going to start off from a **simple CNN arquitecture** and develope different experiments showing benefits of:
#
#
#
# *   Increasing number of filters in convolution layers.
# *   Increasing number of convolution layers.
# *   Taking advantages of Dropout layers.
# *   Taking advantages of Batch normalization layers
# *   Exploring l2 regularization
# .

# %% [markdown]
# ### 1.3.1 Baseline Model

# %% [markdown]
# We will use as a baseline model a 3 convolutional layers model

# %%
base_model = models.Sequential()
base_model.add(layers.Input(shape=(32,32, 3)))

base_model.add(layers.Conv2D(256, (3,3), activation='relu'))
base_model.add(layers.MaxPooling2D(2,2))

base_model.add(layers.Conv2D(128, (3,3), activation='relu'))
base_model.add(layers.MaxPooling2D(2,2))

base_model.add(layers.Conv2D(64, (3,3), activation='relu'))
base_model.add(layers.MaxPooling2D(2,2))


base_model.add(layers.Flatten())

base_model.add(layers.Dense(64, activation='relu'))

base_model.add(layers.Dense(20, activation='softmax'))

base_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 30, 30, 256)         │           7,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 15, 15, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 13, 13, 128)         │         295,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 6, 6, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 4, 4, 64)            │          73,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 2, 2, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 20)                  │           1,300 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 393,748 (1.50 MB)
#  Trainable params: 393,748 (1.50 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Let's compile the model
base_model.compile(optimizer = 'adam',
             loss = 'categorical_crossentropy',
             metrics = ['accuracy'])

# %%
# Train the model
base_history = base_model.fit(train_x,
                    train_y,
                    epochs = 10,
                    batch_size = 32,
                    validation_data = (val_x, val_y))
# Out:
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.0486 - loss: 2.9961 - val_accuracy: 0.0494 - val_loss: 2.9960
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.0509 - loss: 2.9960 - val_accuracy: 0.0460 - val_loss: 2.9960
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.0500 - loss: 2.9959 - val_accuracy: 0.0478 - val_loss: 2.9960
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.0486 - loss: 2.9959 - val_accuracy: 0.0478 - val_loss: 2.9961
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.0508 - loss: 2.9958 - val_accuracy: 0.0502 - val_loss: 2.9960
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.0467 - loss: 2.9960 - val_accuracy: 0.0482 - val_loss: 2.9961
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.0473 - loss: 2.9959 - val_accuracy: 0.0460 - val_loss: 2.9962
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.0519 - loss: 2.9958 - val_accuracy: 0.0460 - val_loss: 2.9960
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.0482 - loss: 2.9960 - val_accuracy: 0.0460 - val_loss: 2.9960
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.0483 - loss: 2.9960 - val_accuracy: 0.0460 - val_loss: 2.9961

# %% [markdown]
# As we can see, this model is insufficient for this problem, we must apply model regularization and develope a more complex arquitecture, including exploring new configurations and tuning.

# %% [markdown]
# ### 1.3.2 Model development and regularization

# %% [markdown]
# In our case, we used Keras Tuner (see Helper functions section) to help design a complex Convolutional Neural Network (CNN). We added more depth to our model, batch normalization layers, dropout layers to stop overfitting and l2 regularizers, that are the ones that fit best our model. After different tests, this is the best regularized model we've found.
# In this case, al values are settled in an average dropout (0.3), l2 (0.0003), kernel size (3)....but they will be redefined in the next tests.

# %%
model = keras.Sequential()
model.add(layers.Input(shape=(32,32, 3)))


model.add(layers.Conv2D(512, kernel_size=3, activation='relu', padding='same',
                        kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())

model.add(layers.Conv2D(256, kernel_size=3, activation='relu', padding='same',
                        kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.3))

model.add(layers.Conv2D(128, kernel_size=3, activation='relu', padding='same',
                        kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.3))

model.add(layers.Conv2D(64, kernel_size=3, activation='relu', padding='same',
                        kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())

model.add(layers.Conv2D(32, kernel_size=3, activation='relu', padding='same',
                        kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.3))

model.add(layers.Flatten())

model.add(layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.3))

model.add(layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.3))

model.add(layers.Dense(20, activation='softmax'))

# %%
model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=0.0005),
        loss="categorical_crossentropy",
        metrics=["accuracy"])

model.summary()
history = model.fit(train_x, train_y,
                    epochs=30,
                    validation_data=(val_x, val_y))
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_32 (Conv2D)                   │ (None, 32, 32, 512)         │          14,336 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_28               │ (None, 32, 32, 512)         │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_33 (Conv2D)                   │ (None, 32, 32, 256)         │       1,179,904 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_29               │ (None, 32, 32, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_21 (MaxPooling2D)      │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_20 (Dropout)                 │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_34 (Conv2D)                   │ (None, 16, 16, 128)         │         295,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_30               │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_22 (MaxPooling2D)      │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_21 (Dropout)                 │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_35 (Conv2D)                   │ (None, 8, 8, 64)            │          73,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_31               │ (None, 8, 8, 64)            │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_36 (Conv2D)                   │ (None, 8, 8, 32)            │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_32               │ (None, 8, 8, 32)            │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_23 (MaxPooling2D)      │ (None, 4, 4, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_22 (Dropout)                 │ (None, 4, 4, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_7 (Flatten)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_33               │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_23 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 128)                 │          65,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_34               │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_24 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 20)                  │           2,580 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,918,964 (7.32 MB)
#  Trainable params: 1,915,700 (7.31 MB)
#  Non-trainable params: 3,264 (12.75 KB)
# Epoch 1/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 39s 22ms/step - accuracy: 0.1419 - loss: 3.5208 - val_accuracy: 0.2525 - val_loss: 2.8075
# Epoch 2/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.2662 - loss: 2.7732 - val_accuracy: 0.3399 - val_loss: 2.4511
# Epoch 3/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.3370 - loss: 2.4834 - val_accuracy: 0.3378 - val_loss: 2.4221
# Epoch 4/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - accuracy: 0.3930 - loss: 2.2485 - val_accuracy: 0.3777 - val_loss: 2.2451
# Epoch 5/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.4388 - loss: 2.0865 - val_accuracy: 0.4078 - val_loss: 2.2031
# Epoch 6/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - accuracy: 0.4673 - loss: 1.9908 - val_accuracy: 0.4665 - val_loss: 2.0057
# Epoch 7/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - accuracy: 0.4938 - loss: 1.9072 - val_accuracy: 0.4633 - val_loss: 2.0128
# Epoch 8/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.5128 - loss: 1.8519 - val_accuracy: 0.5049 - val_loss: 1.8904
# Epoch 9/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - accuracy: 0.5270 - loss: 1.8016 - val_accuracy: 0.5242 - val_loss: 1.8463
# Epoch 10/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.5428 - loss: 1.7605 - val_accuracy: 0.5718 - val_loss: 1.6731
# Epoch 11/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.5551 - loss: 1.7258 - val_accuracy: 0.5472 - val_loss: 1.7565
# Epoch 12/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - accuracy: 0.5694 - loss: 1.6929 - val_accuracy: 0.5039 - val_loss: 1.9411
# Epoch 13/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.5694 - loss: 1.6914 - val_accuracy: 0.4431 - val_loss: 2.2312
# Epoch 14/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - accuracy: 0.5823 - loss: 1.6566 - val_accuracy: 0.3417 - val_loss: 2.7497
# Epoch 15/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.5936 - loss: 1.6279 - val_accuracy: 0.4833 - val_loss: 2.0167
# Epoch 16/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.5951 - loss: 1.6287 - val_accuracy: 0.5868 - val_loss: 1.6469
# Epoch 17/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.6066 - loss: 1.5949 - val_accuracy: 0.2801 - val_loss: 3.0419
# Epoch 18/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.6061 - loss: 1.5859 - val_accuracy: 0.2437 - val_loss: 3.2710
# Epoch 19/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.6095 - loss: 1.5820 - val_accuracy: 0.3135 - val_loss: 3.0258
# Epoch 20/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - accuracy: 0.6116 - loss: 1.5821 - val_accuracy: 0.1081 - val_loss: 4.5375
# Epoch 21/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - accuracy: 0.6124 - loss: 1.5819 - val_accuracy: 0.1389 - val_loss: 5.0337
# Epoch 22/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.6277 - loss: 1.5511 - val_accuracy: 0.1010 - val_loss: 5.9149
# Epoch 23/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - accuracy: 0.6279 - loss: 1.5414 - val_accuracy: 0.0898 - val_loss: 5.3867
# Epoch 24/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.6313 - loss: 1.5332 - val_accuracy: 0.1063 - val_loss: 4.9772
# Epoch 25/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.6357 - loss: 1.5241 - val_accuracy: 0.0779 - val_loss: 5.2210
# Epoch 26/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - accuracy: 0.6382 - loss: 1.5148 - val_accuracy: 0.1762 - val_loss: 3.5865
# Epoch 27/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.6413 - loss: 1.5031 - val_accuracy: 0.1112 - val_loss: 5.1924
# Epoch 28/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.6495 - loss: 1.4914 - val_accuracy: 0.0806 - val_loss: 5.9481
# Epoch 29/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - accuracy: 0.6414 - loss: 1.5053 - val_accuracy: 0.1405 - val_loss: 4.0704
# Epoch 30/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.6429 - loss: 1.5104 - val_accuracy: 0.0786 - val_loss: 7.8741

# %%
plot(history)

# %% [markdown]
# This results are much better, but there is some overfitting from the epoch 15 to the end. Before some manual tuning, we are going to implement some callbacks: EarlyStopping and ReduceLROnPlateau, to stop the training process before the model starts overfitting, and to dynamically adjust the learning rate during training to improve convergence.

# %% [markdown]
# ### 1.3.3 Implementing callbacks and manual tuning

# %% [markdown]
# by adapting the number of units, searching for the best layers, and optimizing other parameters. Additionally, we performed some manual fine-tuning to further refine the model. More details about these experiments and their results are provided in the following sections.

# %%
model = keras.Sequential()
model.add(layers.Input(shape=(32,32, 3)))

model.add(layers.Conv2D(256, kernel_size=5, activation='relu', padding='same',
                      kernel_regularizer=regularizers.l2(0.0002)))
model.add(layers.BatchNormalization())

model.add(layers.Conv2D(256, kernel_size=3, activation='relu', padding='same',
                      kernel_regularizer=regularizers.l2(0.0002)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.3))

model.add(layers.Conv2D(128, kernel_size=3, activation='relu', padding='same',
                      kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.4))

model.add(layers.Conv2D(64, kernel_size=3, activation='relu', padding='same',
                      kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())

model.add(layers.Conv2D(32, kernel_size=3, activation='relu', padding='same',
                      kernel_regularizer=regularizers.l2(0.0004)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.5))

model.add(layers.Flatten())

model.add(layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.0002)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))

model.add(layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))

model.add(layers.Dense(20, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 32, 32, 256)         │          19,456 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 32, 32, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32, 32, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 16, 16, 128)         │         295,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 8, 8, 64)            │          73,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 8, 8, 64)            │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 8, 8, 32)            │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 8, 8, 32)            │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 4, 4, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 4, 4, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 128)                 │          65,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 20)                  │           2,580 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,333,236 (5.09 MB)
#  Trainable params: 1,330,484 (5.08 MB)
#  Non-trainable params: 2,752 (10.75 KB)

# %%
model.compile(
  optimizer=keras.optimizers.Adam(learning_rate=0.0005),
  loss="categorical_crossentropy",
  metrics=["accuracy"]
)



## CALLBACKS
lr_scheduler = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history1 = model.fit(train_x, train_y,
                    epochs=30,
                    validation_data=(val_x, val_y),
                    callbacks=[lr_scheduler, early_stopping])
# Out:
# Epoch 1/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 31s 15ms/step - accuracy: 0.0992 - loss: 3.8608 - val_accuracy: 0.2263 - val_loss: 2.8044 - learning_rate: 5.0000e-04
# Epoch 2/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.1851 - loss: 2.9660 - val_accuracy: 0.2723 - val_loss: 2.6300 - learning_rate: 5.0000e-04
# Epoch 3/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.2408 - loss: 2.7391 - val_accuracy: 0.2744 - val_loss: 2.5698 - learning_rate: 5.0000e-04
# Epoch 4/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.2899 - loss: 2.5689 - val_accuracy: 0.2947 - val_loss: 2.4958 - learning_rate: 5.0000e-04
# Epoch 5/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.3249 - loss: 2.4271 - val_accuracy: 0.3775 - val_loss: 2.2071 - learning_rate: 5.0000e-04
# Epoch 6/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.3577 - loss: 2.3022 - val_accuracy: 0.4023 - val_loss: 2.1285 - learning_rate: 5.0000e-04
# Epoch 7/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.3899 - loss: 2.2023 - val_accuracy: 0.4371 - val_loss: 2.0225 - learning_rate: 5.0000e-04
# Epoch 8/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4149 - loss: 2.1303 - val_accuracy: 0.3727 - val_loss: 2.3631 - learning_rate: 5.0000e-04
# Epoch 9/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4369 - loss: 2.0615 - val_accuracy: 0.3439 - val_loss: 2.3807 - learning_rate: 5.0000e-04
# Epoch 10/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.4493 - loss: 2.0281 - val_accuracy: 0.5066 - val_loss: 1.8319 - learning_rate: 5.0000e-04
# Epoch 11/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4713 - loss: 1.9521 - val_accuracy: 0.4941 - val_loss: 1.8561 - learning_rate: 5.0000e-04
# Epoch 12/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4838 - loss: 1.9322 - val_accuracy: 0.5065 - val_loss: 1.8331 - learning_rate: 5.0000e-04
# Epoch 13/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4894 - loss: 1.9098 - val_accuracy: 0.5208 - val_loss: 1.7882 - learning_rate: 5.0000e-04
# Epoch 14/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5029 - loss: 1.8716 - val_accuracy: 0.5066 - val_loss: 1.8776 - learning_rate: 5.0000e-04
# Epoch 15/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5122 - loss: 1.8490 - val_accuracy: 0.2970 - val_loss: 3.1574 - learning_rate: 5.0000e-04
# Epoch 16/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5182 - loss: 1.8475 - val_accuracy: 0.4373 - val_loss: 2.1327 - learning_rate: 5.0000e-04
# Epoch 17/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5337 - loss: 1.7701 - val_accuracy: 0.5637 - val_loss: 1.6777 - learning_rate: 2.5000e-04
# Epoch 18/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5550 - loss: 1.7169 - val_accuracy: 0.4277 - val_loss: 2.2102 - learning_rate: 2.5000e-04
# Epoch 19/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5581 - loss: 1.6835 - val_accuracy: 0.5830 - val_loss: 1.5901 - learning_rate: 2.5000e-04
# Epoch 20/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5714 - loss: 1.6416 - val_accuracy: 0.5595 - val_loss: 1.6683 - learning_rate: 2.5000e-04
# Epoch 21/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5676 - loss: 1.6338 - val_accuracy: 0.2396 - val_loss: 3.8884 - learning_rate: 2.5000e-04
# Epoch 22/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5750 - loss: 1.6071 - val_accuracy: 0.4743 - val_loss: 1.9785 - learning_rate: 2.5000e-04
# Epoch 23/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5873 - loss: 1.5687 - val_accuracy: 0.5298 - val_loss: 1.7727 - learning_rate: 1.2500e-04
# Epoch 24/30
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5947 - loss: 1.5345 - val_accuracy: 0.4704 - val_loss: 2.1852 - learning_rate: 1.2500e-04

# %%
plot(history1)

# %% [markdown]
# From the top graph (accuracy), we can see that:
#
# The training accuracy (blue line) steadily increases, indicating that the model is learning the training set effectively.
# The validation accuracy (red line) fluctuates considerably, suggesting that the model struggles to generalize consistently. This behavior often points to overfitting, where the model memorizes the training data rather than learning generalizable features.
# In the bottom graph (loss):
#
# The training loss (blue line) decreases smoothly over epochs, confirming that the model is fitting the training data well.
# The validation loss (red line) shows large spikes and volatility, another sign that the model may be overfitting and not adapting well to unseen data.

# %% [markdown]
# ### 1.4 Model tests

# %% [markdown]
# We optimized regularization using both manual tuning and automated tuning (Keras Tuner) to reduce overfitting. Manually, we increased dropout rates (from 0.3 to 0.5 in deeper layers) and adjusted L2 regularization (lower in early layers, higher in later layers) to prevent co-adaptation and large weight values. Automatically, Keras Tuner searched for optimal L2 values, dropout rates, and filter sizes, balancing model complexity and generalization.

# %% [markdown]
# We made three different tests: a less deeper one, a more deeper one and the deepest.

# %% [markdown]
# #### Test 1: Less deeper model

# %%
model = keras.Sequential()

model.add(layers.Input(shape=(32, 32, 3)))

model.add(layers.Conv2D(256, kernel_size=5, activation='relu', padding='same',
                         kernel_regularizer=regularizers.l2(0.0002)))
model.add(layers.BatchNormalization())

model.add(layers.Conv2D(256, kernel_size=3, activation='relu', padding='same',
                         kernel_regularizer=regularizers.l2(0.0002)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.3))

model.add(layers.Conv2D(128, kernel_size=3, activation='relu', padding='same',
                         kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.4))


model.add(layers.Conv2D(32, kernel_size=3, activation='relu', padding='same',
                         kernel_regularizer=regularizers.l2(0.0004)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.5))


model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.0002)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))

model.add(layers.Dense(20, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)                    │ (None, 32, 32, 256)         │          19,456 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 32, 32, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 32, 32, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 32, 32, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 16, 16, 128)         │         295,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 8, 8, 32)            │          36,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 8, 8, 32)            │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 4, 4, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_5 (Dropout)                  │ (None, 4, 4, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 20)                  │          10,260 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,219,124 (4.65 MB)
#  Trainable params: 1,216,756 (4.64 MB)
#  Non-trainable params: 2,368 (9.25 KB)

# %%
model.compile(
  optimizer=keras.optimizers.Adam(learning_rate=0.0005),
  loss="categorical_crossentropy",
  metrics=["accuracy"]
)



## CALLBACKS
lr_scheduler = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history = model.fit(train_x, train_y,
                    epochs=50,
                    batch_size = 32,
                    validation_data=(val_x, val_y),
                    callbacks=[lr_scheduler, early_stopping])

plot(history)
model.evaluate(test_x, test_y)
# Out:
# Epoch 1/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 29s 15ms/step - accuracy: 0.1276 - loss: 3.7247 - val_accuracy: 0.2590 - val_loss: 2.7194 - learning_rate: 5.0000e-04
# Epoch 2/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.2391 - loss: 2.7798 - val_accuracy: 0.2989 - val_loss: 2.4721 - learning_rate: 5.0000e-04
# Epoch 3/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.2909 - loss: 2.5280 - val_accuracy: 0.3651 - val_loss: 2.2270 - learning_rate: 5.0000e-04
# Epoch 4/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.3312 - loss: 2.3615 - val_accuracy: 0.3967 - val_loss: 2.1432 - learning_rate: 5.0000e-04
# Epoch 5/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.3727 - loss: 2.2218 - val_accuracy: 0.3983 - val_loss: 2.1336 - learning_rate: 5.0000e-04
# Epoch 6/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4008 - loss: 2.1132 - val_accuracy: 0.4605 - val_loss: 1.9336 - learning_rate: 5.0000e-04
# Epoch 7/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4283 - loss: 2.0452 - val_accuracy: 0.3524 - val_loss: 2.3911 - learning_rate: 5.0000e-04
# Epoch 8/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4426 - loss: 1.9895 - val_accuracy: 0.4815 - val_loss: 1.8673 - learning_rate: 5.0000e-04
# Epoch 9/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4578 - loss: 1.9551 - val_accuracy: 0.2456 - val_loss: 2.7421 - learning_rate: 5.0000e-04
# Epoch 10/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4634 - loss: 1.9326 - val_accuracy: 0.4909 - val_loss: 1.8482 - learning_rate: 5.0000e-04
# Epoch 11/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4741 - loss: 1.9040 - val_accuracy: 0.5190 - val_loss: 1.7558 - learning_rate: 5.0000e-04
# Epoch 12/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4849 - loss: 1.8750 - val_accuracy: 0.4207 - val_loss: 2.1321 - learning_rate: 5.0000e-04
# Epoch 13/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4961 - loss: 1.8426 - val_accuracy: 0.5325 - val_loss: 1.7353 - learning_rate: 5.0000e-04
# Epoch 14/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4986 - loss: 1.8385 - val_accuracy: 0.3243 - val_loss: 2.5354 - learning_rate: 5.0000e-04
# Epoch 15/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5086 - loss: 1.8007 - val_accuracy: 0.4999 - val_loss: 1.8403 - learning_rate: 5.0000e-04
# Epoch 16/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5126 - loss: 1.7998 - val_accuracy: 0.4913 - val_loss: 1.9124 - learning_rate: 5.0000e-04
# Epoch 17/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5340 - loss: 1.7217 - val_accuracy: 0.5215 - val_loss: 1.8079 - learning_rate: 2.5000e-04
# Epoch 18/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5494 - loss: 1.6756 - val_accuracy: 0.4249 - val_loss: 2.1165 - learning_rate: 2.5000e-04
# Epoch 19/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5519 - loss: 1.6434 - val_accuracy: 0.4604 - val_loss: 1.9953 - learning_rate: 2.5000e-04
# Epoch 20/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5661 - loss: 1.5988 - val_accuracy: 0.5825 - val_loss: 1.5412 - learning_rate: 1.2500e-04
# Epoch 21/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5718 - loss: 1.5712 - val_accuracy: 0.5846 - val_loss: 1.5416 - learning_rate: 1.2500e-04
# Epoch 22/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.
# Epoch 49/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.6145 - loss: 1.3871 - val_accuracy: 0.6466 - val_loss: 1.3007 - learning_rate: 1.0000e-05
# Epoch 50/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.6180 - loss: 1.3838 - val_accuracy: 0.6440 - val_loss: 1.3029 - learning_rate: 1.0000e-05
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6353 - loss: 1.3087
# [1.311787486076355, 0.6388999819755554]

# %% [markdown]
# #### Test 2: Finding the best model

# %%
model = keras.Sequential()
model.add(layers.Input(shape=(32,32, 3)))
model.add(layers.Conv2D(512, kernel_size=5, activation='relu', padding='same',
                        kernel_regularizer=regularizers.l2(0.0002)))
model.add(layers.BatchNormalization())

model.add(layers.Conv2D(256, kernel_size=3, activation='relu', padding='same',
                        kernel_regularizer=regularizers.l2(0.0002)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.3))  # Aumentado para combatir overfitting

model.add(layers.Conv2D(128, kernel_size=3, activation='relu', padding='same',
                        kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.4))  # Aumentado

model.add(layers.Conv2D(64, kernel_size=3, activation='relu', padding='same',
                        kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())

model.add(layers.Conv2D(32, kernel_size=3, activation='relu', padding='same',
                        kernel_regularizer=regularizers.l2(0.0004)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.5))  # Más dropout en la última convolucional

model.add(layers.Flatten())

model.add(layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.0002)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))  # Aumentado

model.add(layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))  # Aumentado

model.add(layers.Dense(20, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_23 (Conv2D)                   │ (None, 32, 32, 512)         │          38,912 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_35               │ (None, 32, 32, 512)         │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_24 (Conv2D)                   │ (None, 32, 32, 256)         │       1,179,904 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_36               │ (None, 32, 32, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_14 (MaxPooling2D)      │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_26 (Dropout)                 │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_25 (Conv2D)                   │ (None, 16, 16, 128)         │         295,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_37               │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_15 (MaxPooling2D)      │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_27 (Dropout)                 │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_26 (Conv2D)                   │ (None, 8, 8, 64)            │          73,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_38               │ (None, 8, 8, 64)            │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_27 (Conv2D)                   │ (None, 8, 8, 32)            │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_39               │ (None, 8, 8, 32)            │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_16 (MaxPooling2D)      │ (None, 4, 4, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_28 (Dropout)                 │ (None, 4, 4, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_5 (Flatten)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_40               │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_29 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 128)                 │          65,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_41               │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_30 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 20)                  │           2,580 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,943,540 (7.41 MB)
#  Trainable params: 1,940,276 (7.40 MB)
#  Non-trainable params: 3,264 (12.75 KB)

# %%
model.compile(
  optimizer=keras.optimizers.Adam(learning_rate=0.0005),
  loss="categorical_crossentropy",
  metrics=["accuracy"]
)



## CALLBACKS
lr_scheduler = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history = model.fit(train_x, train_y,
                    epochs=50,
                    batch_size = 32,
                    validation_data=(val_x, val_y),
                    callbacks=[lr_scheduler, early_stopping])

plot(history)
model.evaluate(test_x, test_y)
# Out:
# Epoch 1/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 24ms/step - accuracy: 0.0977 - loss: 3.9168 - val_accuracy: 0.2151 - val_loss: 2.8425 - learning_rate: 5.0000e-04
# Epoch 2/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.1802 - loss: 3.0056 - val_accuracy: 0.2236 - val_loss: 2.7362 - learning_rate: 5.0000e-04
# Epoch 3/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.2321 - loss: 2.7593 - val_accuracy: 0.2882 - val_loss: 2.5403 - learning_rate: 5.0000e-04
# Epoch 4/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.2771 - loss: 2.6054 - val_accuracy: 0.3178 - val_loss: 2.4398 - learning_rate: 5.0000e-04
# Epoch 5/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.3165 - loss: 2.4649 - val_accuracy: 0.3178 - val_loss: 2.4262 - learning_rate: 5.0000e-04
# Epoch 6/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.3492 - loss: 2.3394 - val_accuracy: 0.4134 - val_loss: 2.1041 - learning_rate: 5.0000e-04
# Epoch 7/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.3793 - loss: 2.2403 - val_accuracy: 0.2101 - val_loss: 3.2008 - learning_rate: 5.0000e-04
# Epoch 8/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.4133 - loss: 2.1554 - val_accuracy: 0.4573 - val_loss: 1.9877 - learning_rate: 5.0000e-04
# Epoch 9/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.4296 - loss: 2.0967 - val_accuracy: 0.4756 - val_loss: 1.9186 - learning_rate: 5.0000e-04
# Epoch 10/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.4465 - loss: 2.0447 - val_accuracy: 0.4955 - val_loss: 1.8739 - learning_rate: 5.0000e-04
# Epoch 11/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.4633 - loss: 1.9885 - val_accuracy: 0.4924 - val_loss: 1.9177 - learning_rate: 5.0000e-04
# Epoch 12/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.4727 - loss: 1.9722 - val_accuracy: 0.5336 - val_loss: 1.7606 - learning_rate: 5.0000e-04
# Epoch 13/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.4940 - loss: 1.9248 - val_accuracy: 0.4886 - val_loss: 1.9041 - learning_rate: 5.0000e-04
# Epoch 14/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.5026 - loss: 1.9013 - val_accuracy: 0.5366 - val_loss: 1.7594 - learning_rate: 5.0000e-04
# Epoch 15/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.5110 - loss: 1.8761 - val_accuracy: 0.5239 - val_loss: 1.7867 - learning_rate: 5.0000e-04
# Epoch 16/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.
# Epoch 43/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - accuracy: 0.6422 - loss: 1.3410 - val_accuracy: 0.6497 - val_loss: 1.3228 - learning_rate: 3.1250e-05
# Epoch 44/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.6429 - loss: 1.3447 - val_accuracy: 0.6549 - val_loss: 1.3064 - learning_rate: 3.1250e-05
# Epoch 45/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.6453 - loss: 1.3393 - val_accuracy: 0.6612 - val_loss: 1.2736 - learning_rate: 1.5625e-05
# Epoch 46/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.6459 - loss: 1.3390 - val_accuracy: 0.6599 - val_loss: 1.2739 - learning_rate: 1.5625e-05
# Epoch 47/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.6494 - loss: 1.3242 - val_accuracy: 0.6583 - val_loss: 1.2794 - learning_rate: 1.5625e-05
# Epoch 48/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - accuracy: 0.6410 - loss: 1.3402 - val_accuracy: 0.6617 - val_loss: 1.2685 - learning_rate: 1.5625e-05
# Epoch 49/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - accuracy: 0.6452 - loss: 1.3219 - val_accuracy: 0.6573 - val_loss: 1.2828 - learning_rate: 1.5625e-05
# Epoch 50/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - accuracy: 0.6455 - loss: 1.3265 - val_accuracy: 0.6583 - val_loss: 1.2695 - learning_rate: 1.5625e-05
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6613 - loss: 1.2749
# [1.2709192037582397, 0.6622999906539917]

# %% [markdown]
# #### Test 3: Can we go deeper?

# %%
model = keras.Sequential()
model.add(layers.Input(shape=(32, 32, 3)))

# Increased number of convolutional layers to capture more complex features
model.add(layers.Conv2D(256, kernel_size=5, activation='relu', padding='same',
                         kernel_regularizer=regularizers.l2(0.0002)))
model.add(layers.BatchNormalization())

model.add(layers.Conv2D(256, kernel_size=3, activation='relu', padding='same',
                         kernel_regularizer=regularizers.l2(0.0002)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.3))

model.add(layers.Conv2D(128, kernel_size=3, activation='relu', padding='same',
                         kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())

model.add(layers.Conv2D(128, kernel_size=3, activation='relu', padding='same',
                         kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.4))

model.add(layers.Conv2D(64, kernel_size=3, activation='relu', padding='same',
                         kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())

model.add(layers.Conv2D(64, kernel_size=3, activation='relu', padding='same',
                         kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.5))

model.add(layers.Flatten())

# Increased number of dense layers to enhance generalization
model.add(layers.Dense(1024, activation='relu', kernel_regularizer=regularizers.l2(0.0002)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))

model.add(layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.0002)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))

model.add(layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))

model.add(layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.0003)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))

model.add(layers.Dense(20, activation='softmax'))  

model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_17 (Conv2D)                   │ (None, 32, 32, 256)         │          19,456 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_25               │ (None, 32, 32, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_18 (Conv2D)                   │ (None, 32, 32, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_26               │ (None, 32, 32, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_19 (Dropout)                 │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_19 (Conv2D)                   │ (None, 16, 16, 128)         │         295,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_27               │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_20 (Conv2D)                   │ (None, 16, 16, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_28               │ (None, 16, 16, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_20 (Dropout)                 │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_21 (Conv2D)                   │ (None, 8, 8, 64)            │          73,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_29               │ (None, 8, 8, 64)            │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_22 (Conv2D)                   │ (None, 8, 8, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_30               │ (None, 8, 8, 64)            │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_13 (MaxPooling2D)      │ (None, 4, 4, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_21 (Dropout)                 │ (None, 4, 4, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 1024)                │       1,049,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_31               │ (None, 1024)                │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_22 (Dropout)                 │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_32               │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_23 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_33               │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_24 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_34               │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_25 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 20)                  │           2,580 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,915,348 (11.12 MB)
#  Trainable params: 2,909,716 (11.10 MB)
#  Non-trainable params: 5,632 (22.00 KB)

# %%
model.compile(
  optimizer=keras.optimizers.Adam(learning_rate=0.0005),
  loss="categorical_crossentropy",
  metrics=["accuracy"]
)



## CALLBACKS
lr_scheduler = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history = model.fit(train_x, train_y,
                    epochs=50,
                    batch_size = 32,
                    validation_data=(val_x, val_y),
                    callbacks=[lr_scheduler, early_stopping])

plot(history)
model.evaluate(test_x, test_y)
# Out:
# Epoch 1/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 37s 17ms/step - accuracy: 0.0719 - loss: 4.4284 - val_accuracy: 0.1882 - val_loss: 3.3096 - learning_rate: 5.0000e-04
# Epoch 2/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - accuracy: 0.1490 - loss: 3.4571 - val_accuracy: 0.1998 - val_loss: 3.2165 - learning_rate: 5.0000e-04
# Epoch 3/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.1936 - loss: 3.2298 - val_accuracy: 0.2620 - val_loss: 2.9608 - learning_rate: 5.0000e-04
# Epoch 4/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.2451 - loss: 3.0273 - val_accuracy: 0.2804 - val_loss: 2.8362 - learning_rate: 5.0000e-04
# Epoch 5/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.2894 - loss: 2.8253 - val_accuracy: 0.3622 - val_loss: 2.5408 - learning_rate: 5.0000e-04
# Epoch 6/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.3293 - loss: 2.6569 - val_accuracy: 0.3837 - val_loss: 2.4434 - learning_rate: 5.0000e-04
# Epoch 7/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.3741 - loss: 2.5004 - val_accuracy: 0.3879 - val_loss: 2.4188 - learning_rate: 5.0000e-04
# Epoch 8/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.4124 - loss: 2.3780 - val_accuracy: 0.4586 - val_loss: 2.2073 - learning_rate: 5.0000e-04
# Epoch 9/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.4386 - loss: 2.3112 - val_accuracy: 0.4757 - val_loss: 2.1206 - learning_rate: 5.0000e-04
# Epoch 10/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.4592 - loss: 2.2284 - val_accuracy: 0.4291 - val_loss: 2.3607 - learning_rate: 5.0000e-04
# Epoch 11/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0
# Epoch 38/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.7148 - loss: 1.2617 - val_accuracy: 0.6753 - val_loss: 1.3872 - learning_rate: 3.1250e-05
# Epoch 39/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.7126 - loss: 1.2558 - val_accuracy: 0.6707 - val_loss: 1.3997 - learning_rate: 3.1250e-05
# Epoch 40/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.7179 - loss: 1.2373 - val_accuracy: 0.6677 - val_loss: 1.4080 - learning_rate: 3.1250e-05
# Epoch 41/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.7225 - loss: 1.2248 - val_accuracy: 0.6851 - val_loss: 1.3473 - learning_rate: 1.5625e-05
# Epoch 42/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.7230 - loss: 1.2094 - val_accuracy: 0.6817 - val_loss: 1.3559 - learning_rate: 1.5625e-05
# Epoch 43/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.7261 - loss: 1.2188 - val_accuracy: 0.6841 - val_loss: 1.3525 - learning_rate: 1.5625e-05
# Epoch 44/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.7194 - loss: 1.2284 - val_accuracy: 0.6804 - val_loss: 1.3510 - learning_rate: 1.5625e-05
# Epoch 45/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.7267 - loss: 1.2006 - val_accuracy: 0.6852 - val_loss: 1.3441 - learning_rate: 1.0000e-05
# Epoch 46/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.7272 - loss: 1.1980 - val_accuracy: 0.6884 - val_loss: 1.3383 - learning_rate: 1.0000e-05
# Epoch 47/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.7295 - loss: 1.1940 - val_accuracy: 0.6857 - val_loss: 1.3361 - learning_rate: 1.0000e-05
# Epoch 48/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.7275 - loss: 1.2039 - val_accuracy: 0.6858 - val_loss: 1.3437 - learning_rate: 1.0000e-05
# Epoch 49/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.7289 - loss: 1.1921 - val_accuracy: 0.6899 - val_loss: 1.3326 - learning_rate: 1.0000e-05
# Epoch 50/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.7317 - loss: 1.1812 - val_accuracy: 0.6883 - val_loss: 1.3368 - learning_rate: 1.0000e-05
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6911 - loss: 1.3522
# [1.368617057800293, 0.6833999752998352]

# %% [markdown]
# ##### Conclusions

# %%
# Model names
models = [
    "Less deeper CNN",
    "Best CNN",
    "Deepest CNN",
]

# Test accuracies for each model
test_accuracies = [0.6353, 0.6613, 0.6833]
test_loss = [1.3087, 1.2749, 1.3522]


x = np.arange(len(models))
width = 0.4

fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(x - width/2, test_accuracies, width, label="Test Accuracy", color="royalblue")
ax.bar(x + width/2, test_loss, width, label="Test Loss", color="pink")
ax.set_xlabel("Models")
ax.set_ylabel("Accuracy")
ax.set_title("CIFAR 100 - Model depth comparison results")
ax.set_xticks(x)
ax.set_xticklabels(models, rotation=30, ha="right")
ax.set_ylim(0, 1.5)
ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# While the deepest model gets the best accuracy (0.6833), we can see that there is several overfitting. The same as the simplest model. Also the loss values are higher in these two. For these reasons, we will choose as our model the second one, which has the next structure:

# %%
import visualkeras
from tensorflow import keras
visualkeras.layered_view(model, legend=True)  # Show model structure
# Out:
# /usr/local/lib/python3.11/dist-packages/visualkeras/layered.py:86: UserWarning: The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.
#   warnings.warn("The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.")
# <PIL.Image.Image image mode=RGBA size=965x209>

# %% [markdown]
# ## Comparing optimizers

# %% [markdown]
# We should try manually another optimizer in case this could work better

# %% [markdown]
# #### New optimizer: RMSprop

# %%
model.compile(
  optimizer=keras.optimizers.RMSprop(learning_rate=0.0005),
  loss="categorical_crossentropy",
  metrics=["accuracy"]
)


## CALLBACKS
lr_scheduler = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history3 = model.fit(train_x, train_y,
                    epochs=50,
                    validation_data=(val_x, val_y),
                    callbacks=[lr_scheduler, early_stopping])
# Out:
# Epoch 1/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 35s 21ms/step - accuracy: 0.6259 - loss: 1.4336 - val_accuracy: 0.6281 - val_loss: 1.4216 - learning_rate: 5.0000e-04
# Epoch 2/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.
# Epoch 29/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7068 - loss: 1.1618 - val_accuracy: 0.6959 - val_loss: 1.1914 - learning_rate: 1.5625e-05
# Epoch 30/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7118 - loss: 1.1544 - val_accuracy: 0.6948 - val_loss: 1.1900 - learning_rate: 1.5625e-05
# Epoch 31/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7099 - loss: 1.1637 - val_accuracy: 0.6959 - val_loss: 1.1904 - learning_rate: 1.5625e-05
# Epoch 32/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7124 - loss: 1.1423 - val_accuracy: 0.6927 - val_loss: 1.1880 - learning_rate: 1.5625e-05
# Epoch 33/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7075 - loss: 1.1563 - val_accuracy: 0.6922 - val_loss: 1.1882 - learning_rate: 1.5625e-05
# Epoch 34/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7114 - loss: 1.1586 - val_accuracy: 0.6941 - val_loss: 1.1897 - learning_rate: 1.5625e-05
# Epoch 35/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7104 - loss: 1.1592 - val_accuracy: 0.6966 - val_loss: 1.1851 - learning_rate: 1.0000e-05
# Epoch 36/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7118 - loss: 1.1453 - val_accuracy: 0.6950 - val_loss: 1.1842 - learning_rate: 1.0000e-05
# Epoch 37/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7180 - loss: 1.1282 - val_accuracy: 0.6948 - val_loss: 1.1855 - learning_rate: 1.0000e-05
# Epoch 38/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7120 - loss: 1.1451 - val_accuracy: 0.6964 - val_loss: 1.1837 - learning_rate: 1.0000e-05
# Epoch 39/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7123 - loss: 1.1427 - val_accuracy: 0.6945 - val_loss: 1.1883 - learning_rate: 1.0000e-05
# Epoch 40/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7133 - loss: 1.1464 - val_accuracy: 0.6960 - val_loss: 1.1807 - learning_rate: 1.0000e-05
# Epoch 41/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7112 - loss: 1.1344 - val_accuracy: 0.6943 - val_loss: 1.1875 - learning_rate: 1.0000e-05
# Epoch 42/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7192 - loss: 1.1246 - val_accuracy: 0.6961 - val_loss: 1.1859 - learning_rate: 1.0000e-05
# Epoch 43/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7156 - loss: 1.1312 - val_accuracy: 0.6955 - val_loss: 1.1884 - learning_rate: 1.0000e-05
# Epoch 44/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7179 - loss: 1.1268 - val_accuracy: 0.6966 - val_loss: 1.1844 - learning_rate: 1.0000e-05
# Epoch 45/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7137 - loss: 1.1403 - val_accuracy: 0.6952 - val_loss: 1.1800 - learning_rate: 1.0000e-05
# Epoch 46/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7118 - loss: 1.1348 - val_accuracy: 0.6973 - val_loss: 1.1780 - learning_rate: 1.0000e-05
# Epoch 47/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7164 - loss: 1.1223 - val_accuracy: 0.6973 - val_loss: 1.1809 - learning_rate: 1.0000e-05
# Epoch 48/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7173 - loss: 1.1313 - val_accuracy: 0.6966 - val_loss: 1.1810 - learning_rate: 1.0000e-05
# Epoch 49/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7162 - loss: 1.1289 - val_accuracy: 0.6951 - val_loss: 1.1796 - learning_rate: 1.0000e-05
# Epoch 50/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - accuracy: 0.7184 - loss: 1.1237 - val_accuracy: 0.6942 - val_loss: 1.1805 - learning_rate: 1.0000e-05

# %%
plot(history3)
model.evaluate(test_x, test_y)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6979 - loss: 1.2049
# [1.2058618068695068, 0.6944000124931335]

# %% [markdown]
# ##### Conclusions

# %% [markdown]
# While the model compiled with Adam got a test accuracy value of 0.6613, this one gets aproximately 0.6945. The problem is the same as with the deepest model, there is some overfitting over the last epochs. So in this case, we are going to stick to our previous optimizer (Adam).

# %% [markdown]
# ### 1.3.5 Testing new arquitectures

# %% [markdown]
# #### Residual connections

# %%
def residual_block(x, filters, kernel_size, regularizer):

    residual = x

    x = layers.Conv2D(filters, kernel_size, activation='relu', padding='same',
                      kernel_regularizer=regularizer)(x)
    x = layers.BatchNormalization()(x)

    x = layers.Conv2D(filters, kernel_size, activation='relu', padding='same',
                      kernel_regularizer=regularizer)(x)
    x = layers.BatchNormalization()(x)

    if residual.shape[-1] != x.shape[-1]:
        residual = layers.Conv2D(filters, kernel_size=1, padding='same')(residual)

    x = layers.add([x, residual])

    return x


input_layer = layers.Input(shape=(32,32, 3))

x = layers.Conv2D(512, kernel_size=5, activation='relu', padding='same',
                  kernel_regularizer=regularizers.l2(0.0002))(input_layer)
x = layers.BatchNormalization()(x)
x = residual_block(x, 512, kernel_size=5, regularizer=regularizers.l2(0.0002))


x = layers.Conv2D(256, kernel_size=3, activation='relu', padding='same',
                  kernel_regularizer=regularizers.l2(0.0002))(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Dropout(0.3)(x)


x = residual_block(x, 128, kernel_size=3, regularizer=regularizers.l2(0.0003))
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Dropout(0.4)(x)

x = residual_block(x, 64, kernel_size=3, regularizer=regularizers.l2(0.0003))

x = residual_block(x, 32, kernel_size=3, regularizer=regularizers.l2(0.0004))
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Dropout(0.5)(x)

x = layers.Flatten()(x)

x = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.0002))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.5)(x)

x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.0003))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.5)(x)


output_layer = layers.Dense(20, activation='softmax')(x)

model = tf.keras.Model(inputs=input_layer, outputs=output_layer)

model.summary()
# Out:
# Model: "functional_317"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_47            │ (None, 32, 32, 3)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_158 (Conv2D)       │ (None, 32, 32, 512)    │         38,912 │ input_layer_47[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_197   │ (None, 32, 32, 512)    │          2,048 │ conv2d_158[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_159 (Conv2D)       │ (None, 32, 32, 512)    │      6,554,112 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_198   │ (None, 32, 32, 512)    │          2,048 │ conv2d_159[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_160 (Conv2D)       │ (None, 32, 32, 512)    │      6,554,112 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_199   │ (None, 32, 32, 512)    │          2,048 │ conv2d_160[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_6 (Add)               │ (None, 32, 32, 512)    │              0 │ batch_normalization_1… │
# │                           │                        │                │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_161 (Conv2D)       │ (None, 32, 32, 256)    │      1,179,904 │ add_6[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_200   │ (None, 32, 32, 256)    │          1,024 │ conv2d_161[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_89          │ (None, 16, 16, 256)    │              0 │ batch_normalization_2… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_128 (Dropout)     │ (None, 16, 16, 256)    │              0 │ max_pooling2d_89[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_162 (Conv2D)       │ (None, 16, 16, 128)    │        295,040 │ dropout_128[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_201   │ (None, 16, 16, 128)    │            512 │ conv2d_162[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_163 (Conv2D)       │ (None, 16, 16, 128)    │        147,584 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_202   │ (None, 16, 16, 128)    │            512 │ conv2d_163[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_164 (Conv2D)       │ (None, 16, 16, 128)    │         32,896 │ dropout_128[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_7 (Add)               │ (None, 16, 16, 128)    │              0 │ batch_normalization_2… │
# │                           │                        │                │ conv2d_164[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_90          │ (None, 8, 8, 128)      │              0 │ add_7[0][0]            │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_129 (Dropout)     │ (None, 8, 8, 128)      │              0 │ max_pooling2d_90[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_165 (Conv2D)       │ (None, 8, 8, 64)       │         73,792 │ dropout_129[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_203   │ (None, 8, 8, 64)       │            256 │ conv2d_165[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_166 (Conv2D)       │ (None, 8, 8, 64)       │         36,928 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_204   │ (None, 8, 8, 64)       │            256 │ conv2d_166[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_167 (Conv2D)       │ (None, 8, 8, 64)       │          8,256 │ dropout_129[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_8 (Add)               │ (None, 8, 8, 64)       │              0 │ batch_normalization_2… │
# │                           │                        │                │ conv2d_167[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_168 (Conv2D)       │ (None, 8, 8, 32)       │         18,464 │ add_8[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_205   │ (None, 8, 8, 32)       │            128 │ conv2d_168[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_169 (Conv2D)       │ (None, 8, 8, 32)       │          9,248 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_206   │ (None, 8, 8, 32)       │            128 │ conv2d_169[0][0]       │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_170 (Conv2D)       │ (None, 8, 8, 32)       │          2,080 │ add_8[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_9 (Add)               │ (None, 8, 8, 32)       │              0 │ batch_normalization_2… │
# │                           │                        │                │ conv2d_170[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_91          │ (None, 4, 4, 32)       │              0 │ add_9[0][0]            │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_130 (Dropout)     │ (None, 4, 4, 32)       │              0 │ max_pooling2d_91[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_29 (Flatten)      │ (None, 512)            │              0 │ dropout_130[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_77 (Dense)          │ (None, 512)            │        262,656 │ flatten_29[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_207   │ (None, 512)            │          2,048 │ dense_77[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_131 (Dropout)     │ (None, 512)            │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_78 (Dense)          │ (None, 128)            │         65,664 │ dropout_131[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_208   │ (None, 128)            │            512 │ dense_78[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_132 (Dropout)     │ (None, 128)            │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_79 (Dense)          │ (None, 20)             │          2,580 │ dropout_132[0][0]      │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 15,293,748 (58.34 MB)
#  Trainable params: 15,287,988 (58.32 MB)
#  Non-trainable params: 5,760 (22.50 KB)

# %%
# Compile the model
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0005),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

lr_scheduler = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

history4 = model.fit(train_x, train_y,
                    epochs=50,
                    batch_size = 32,
                    validation_data=(val_x, val_y),
                     callbacks=[early_stopping, lr_scheduler])
plot(history4)
model.evaluate(test_x, test_y)
# Out:
# Epoch 1/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 164s 119ms/step - accuracy: 0.0898 - loss: 4.2235 - val_accuracy: 0.2109 - val_loss: 3.1218 - learning_rate: 5.0000e-04
# Epoch 2/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 147s 117ms/step - accuracy: 0.1726 - loss: 3.2254 - val_accuracy: 0.2465 - val_loss: 2.8307 - learning_rate: 5.0000e-04
# Epoch 3/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 147s 117ms/step - accuracy: 0.2172 - loss: 2.9111 - val_accuracy: 0.2753 - val_loss: 2.6713 - learning_rate: 5.0000e-04
# Epoch 4/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 147s 117ms/step - accuracy: 0.2587 - loss: 2.7078 - val_accuracy: 0.2865 - val_loss: 2.6241 - learning_rate: 5.0000e-04
# Epoch 5/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 146s 117ms/step - accuracy: 0.2849 - loss: 2.5790 - val_accuracy: 0.2880 - val_loss: 2.5817 - learning_rate: 5.0000e-04
# Epoch 6/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 146s 117ms/step - accuracy: 0.3098 - loss: 2.5052 - val_accuracy: 0.3536 - val_loss: 2.3493 - learning_rate: 5.0000e-04
# Epoch 7/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 146s 117ms/step - accuracy: 0.3315 - loss: 2.4473 - val_accuracy: 0.3812 - val_loss: 2.2852 - learning_rate: 5.0000e-04
# Epoch 8/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 146s 117ms/step - accuracy: 0.3526 - loss: 2.3893 - val_accuracy: 0.3616 - val_loss: 2.3635 - learning_rate: 5.0000e-04
# Epoch 9/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 146s 117ms/step - accuracy: 0.3757 - loss: 2.3248 - val_accuracy: 0.3920 - val_loss: 2.2691 - learning_rate: 5.0000e-04
# Epoch 10/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 145s 116ms/step - accuracy: 0.3975 - loss: 2.2564 - val_accuracy: 0.4336 - val_loss: 2.1389 - learning_rate: 5.0000e-04
# Epoch 11/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 145s 116ms/step - accuracy: 0.4206 - loss: 2.1867 - val_accuracy: 0.4553 - val_loss: 2.0671 - learning_rate: 5.0000e-04
# Epoch 12/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 145s 116ms/step - accuracy: 0.4412 - loss: 2.1447 - val_accuracy: 0.3677 - val_loss: 2.4862 - learning_rate: 5.0000e-04
# Epoch 13/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 145s 116ms/step - accuracy: 0.4531 - loss: 2.0957 - val_accuracy: 0.3653 - val_loss: 2.5362 - learning_rate: 5.0000e-04
# Epoch 14/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━
# Epoch 38/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 142s 114ms/step - accuracy: 0.7396 - loss: 1.0744 - val_accuracy: 0.6471 - val_loss: 1.4602 - learning_rate: 3.1250e-05
# Epoch 39/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 142s 114ms/step - accuracy: 0.7439 - loss: 1.0615 - val_accuracy: 0.6468 - val_loss: 1.4559 - learning_rate: 1.5625e-05
# Epoch 40/50
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 142s 114ms/step - accuracy: 0.7536 - loss: 1.0371 - val_accuracy: 0.6493 - val_loss: 1.4424 - learning_rate: 1.5625e-05
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step - accuracy: 0.6473 - loss: 1.4297
# [1.4191186428070068, 0.6485999822616577]

# %% [markdown]
# #### Inception blocks

# %%
def inception_block(x, filters, kernel_regularizer=None):
    f1, f3r, f3, f5r, f5, fpp = filters

    conv1x1 = layers.Conv2D(f1, (1, 1), activation='relu', padding='same', kernel_regularizer=kernel_regularizer)(x)

    conv3x3 = layers.Conv2D(f3r, (1, 1), activation='relu', padding='same', kernel_regularizer=kernel_regularizer)(x)
    conv3x3 = layers.Conv2D(f3, (3, 3), activation='relu', padding='same', kernel_regularizer=kernel_regularizer)(conv3x3)

    conv5x5 = layers.Conv2D(f5r, (1, 1), activation='relu', padding='same', kernel_regularizer=kernel_regularizer)(x)
    conv5x5 = layers.Conv2D(f5, (5, 5), activation='relu', padding='same', kernel_regularizer=kernel_regularizer)(conv5x5)

    pool_proj = layers.MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    pool_proj = layers.Conv2D(fpp, (1, 1), activation='relu', padding='same', kernel_regularizer=kernel_regularizer)(pool_proj)

    x = layers.Concatenate()([conv1x1, conv3x3, conv5x5, pool_proj])

    return x


input_layer = layers.Input(shape=(32, 32, 3))

x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(input_layer)
x = layers.MaxPooling2D((2, 2))(x)

x = inception_block(x, [64, 128, 128, 32, 32, 32], kernel_regularizer=regularizers.l2(0.0002))


x = layers.MaxPooling2D((2, 2))(x)
x = layers.Dropout(0.4)(x)

x = layers.Flatten()(x)
x = layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.0002))(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.5)(x)

output_layer = layers.Dense(20, activation='softmax')(x)

model = models.Model(inputs=input_layer, outputs=output_layer)

model.summary()
# Out:
# Model: "functional_159"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_24            │ (None, 32, 32, 3)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_119 (Conv2D)       │ (None, 32, 32, 64)     │          1,792 │ input_layer_24[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_69          │ (None, 16, 16, 64)     │              0 │ conv2d_119[0][0]       │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_121 (Conv2D)       │ (None, 16, 16, 128)    │          8,320 │ max_pooling2d_69[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_123 (Conv2D)       │ (None, 16, 16, 32)     │          2,080 │ max_pooling2d_69[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_70          │ (None, 16, 16, 64)     │              0 │ max_pooling2d_69[0][0] │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_120 (Conv2D)       │ (None, 16, 16, 64)     │          4,160 │ max_pooling2d_69[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_122 (Conv2D)       │ (None, 16, 16, 128)    │        147,584 │ conv2d_121[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_124 (Conv2D)       │ (None, 16, 16, 32)     │         25,632 │ conv2d_123[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_125 (Conv2D)       │ (None, 16, 16, 32)     │          2,080 │ max_pooling2d_70[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 16, 16, 256)    │              0 │ conv2d_120[0][0],      │
# │                           │                        │                │ conv2d_122[0][0],      │
# │                           │                        │                │ conv2d_124[0][0],      │
# │                           │                        │                │ conv2d_125[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_71          │ (None, 8, 8, 256)      │              0 │ concatenate[0][0]      │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_54 (Dropout)      │ (None, 8, 8, 256)      │              0 │ max_pooling2d_71[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_6 (Flatten)       │ (None, 16384)          │              0 │ dropout_54[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_39 (Dense)          │ (None, 512)            │      8,389,120 │ flatten_6[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_171   │ (None, 512)            │          2,048 │ dense_39[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_55 (Dropout)      │ (None, 512)            │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_40 (Dense)          │ (None, 20)             │         10,260 │ dropout_55[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 8,593,076 (32.78 MB)
#  Trainable params: 8,592,052 (32.78 MB)
#  Non-trainable params: 1,024 (4.00 KB)

# %%
# Compile the model
model.compile(
    optimizer=keras.optimizers.RMSprop(),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

lr_scheduler = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5)
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

history5 = model.fit(train_x, train_y,
                    epochs=150,
                    batch_size = 32,
                    validation_data=(val_x, val_y),
                     callbacks=[lr_scheduler, early_stopping])
plot(history5)
model.evaluate(test_x, test_y)
# Out:
# Epoch 1/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.3535 - loss: 2.1912 - val_accuracy: 0.4082 - val_loss: 2.0029 - learning_rate: 0.0010
# Epoch 2/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3562 - loss: 2.1835 - val_accuracy: 0.4115 - val_loss: 2.0055 - learning_rate: 0.0010
# Epoch 3/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3606 - loss: 2.1763 - val_accuracy: 0.4074 - val_loss: 2.0155 - learning_rate: 0.0010
# Epoch 4/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3574 - loss: 2.1700 - val_accuracy: 0.4113 - val_loss: 1.9938 - learning_rate: 0.0010
# Epoch 5/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3601 - loss: 2.1700 - val_accuracy: 0.3966 - val_loss: 2.0328 - learning_rate: 0.0010
# Epoch 6/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3594 - loss: 2.1746 - val_accuracy: 0.4042 - val_loss: 2.0103 - learning_rate: 0.0010
# Epoch 7/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3593 - loss: 2.1713 - val_accuracy: 0.3453 - val_loss: 2.2143 - learning_rate: 0.0010
# Epoch 8/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3617 - loss: 2.1681 - val_accuracy: 0.3825 - val_loss: 2.0971 - learning_rate: 0.0010
# Epoch 9/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3549 - loss: 2.1864 - val_accuracy: 0.4169 - val_loss: 1.9719 - learning_rate: 0.0010
# Epoch 10/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3573 - loss: 2.1790 - val_accuracy: 0.4119 - val_loss: 1.9938 - learning_rate: 0.0010
# Epoch 11/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3580 - loss: 2.1668 - val_accuracy: 0.3804 - val_loss: 2.0970 - learning_rate: 0.0010
# Epoch 12/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3583 - loss: 2.1835 - val_accuracy: 0.3751 - val_loss: 2.1442 - learning_rate: 0.0010
# Epoch 13/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3613 - loss: 2.1747 - val_accuracy: 0.4152 - val_loss: 1.9948 - learning_rate: 0.0010
# Epoch 14/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3572 - loss: 2.1732 - val_accuracy: 0.4007 - val_loss: 2.0246 - learning_rate: 0.0010
# Epoch 15/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3719 - loss: 2.1413 - val_accuracy: 0.4263 - val_loss: 1.9508 - learning_rate: 5.0000e-04
# Epoch 16/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3746 - loss: 2.1121 - val_accuracy: 0.4275 - val_loss: 1.9458 - learning_rate: 5.0000e-04
# Epoch 17/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3795 - loss: 2.1008 - val_accuracy: 0.4365 - val_loss: 1.9211 - learning_rate: 5.0000e-04
# Epoch 18/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3839 - loss: 2.0897 - val_accuracy: 0.4343 - val_loss: 1.9256 - learning_rate: 5.0000e-04
# Epoch 19/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3809 - loss: 2.0952 - val_accuracy: 0.4390 - val_loss: 1.9108 - learning_rate: 5.0000e-04
# Epoch 20/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3829 - loss: 2.0927 - val_accuracy: 0.4336 - val_loss: 1.9245 - learning_rate: 5.0000e-04
# Epoch 21/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3821 - loss: 2.0832 - val_accuracy: 0.4385 - val_loss: 1.9235 - learning_rate: 5.0000e-04
# Epoch 22/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3810 - loss: 2.0844 - val_accuracy: 0.4302 - val_loss: 1.9336 - learning_rate: 5.0000e-04
# Epoch 23/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3834 - loss: 2.0805 - val_accuracy: 0.4374 - val_loss: 1.9096 - learning_rate: 5.0000e-04
# Epoch 24/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3860 - loss: 2.0766 - val_accuracy: 0.4228 - val_loss: 1.9409 - learning_rate: 5.0000e-04
# Epoch 25/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3858 - loss: 2.0769 - val_accuracy: 0.4298 - val_loss: 1.9337 - learning_rate: 5.0000e-04
# Epoch 26/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3845 - loss: 2.0832 - val_accuracy: 0.4331 - val_loss: 1.9210 - learning_rate: 5.0000e-04
# Epoch 27/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3877 - loss: 2.0745 - val_accuracy: 0.4331 - val_loss: 1.9141 - learning_rate: 5.0000e-04
# Epoch 28/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3867 - loss: 2.0720 - val_accuracy: 0.4307 - val_loss: 1.9238 - learning_rate: 5.0000e-04
# Epoch 29/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3964 - loss: 2.0391 - val_accuracy: 0.4471 - val_loss: 1.8874 - learning_rate: 2.5000e-04
# Epoch 30/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3911 - loss: 2.0540 - val_accuracy: 0.4469 - val_loss: 1.8715 - learning_rate: 2.5000e-04
# Epoch 31/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3927 - loss: 2.0477 - val_accuracy: 0.4477 - val_loss: 1.8726 - learning_rate: 2.5000e-04
# Epoch 32/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3954 - loss: 2.0439 - val_accuracy: 0.4459 - val_loss: 1.8762 - learning_rate: 2.5000e-04
# Epoch 33/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3928 - loss: 2.0349 - val_accuracy: 0.4474 - val_loss: 1.8654 - learning_rate: 2.5000e-04
# Epoch 34/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3959 - loss: 2.0302 - val_accuracy: 0.4458 - val_loss: 1.8716 - learning_rate: 2.5000e-04
# Epoch 35/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3954 - loss: 2.0305 - val_accuracy: 0.4444 - val_loss: 1.8801 - learning_rate: 2.5000e-04
# Epoch 36/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3923 - loss: 2.0391 - val_accuracy: 0.4474 - val_loss: 1.8718 - learning_rate: 2.5000e-04
# Epoch 37/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3968 - loss: 2.0312 - val_accuracy: 0.4407 - val_loss: 1.8704 - learning_rate: 2.5000e-04
# Epoch 38/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.3983 - loss: 2.0221 - val_accuracy: 0.4407 - val_loss: 1.8891 - learning_rate: 2.5000e-04
# Epoch 39/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4012 - loss: 2.0096 - val_accuracy: 0.4516 - val_loss: 1.8539 - learning_rate: 1.2500e-04
# Epoch 40/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4019 - loss: 2.0178 - val_accuracy: 0.4536 - val_loss: 1.8503 - learning_rate: 1.2500e-04
# Epoch 41/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4020 - loss: 2.0153 - val_accuracy: 0.4550 - val_loss: 1.8400 - learning_rate: 1.2500e-04
# Epoch 42/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4069 - loss: 2.0071 - val_accuracy: 0.4557 - val_loss: 1.8437 - learning_rate: 1.2500e-04
# Epoch 43/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4075 - loss: 2.0013 - val_accuracy: 0.4590 - val_loss: 1.8398 - learning_rate: 1.2500e-04
# Epoch 44/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4038 - loss: 2.0046 - val_accuracy: 0.4554 - val_loss: 1.8414 - learning_rate: 1.2500e-04
# Epoch 45/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4047 - loss: 2.0075 - val_accuracy: 0.4568 - val_loss: 1.8407 - learning_rate: 1.2500e-04
# Epoch 46/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4081 - loss: 1.9962 - val_accuracy: 0.4553 - val_loss: 1.8461 - learning_rate: 1.2500e-04
# Epoch 47/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4053 - loss: 1.9953 - val_accuracy: 0.4545 - val_loss: 1.8460 - learning_rate: 1.2500e-04
# Epoch 48/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.
150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4149 - loss: 1.9694 - val_accuracy: 0.4651 - val_loss: 1.8110 - learning_rate: 1.0000e-05
# Epoch 120/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4129 - loss: 1.9707 - val_accuracy: 0.4637 - val_loss: 1.8114 - learning_rate: 1.0000e-05
# Epoch 121/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4154 - loss: 1.9670 - val_accuracy: 0.4635 - val_loss: 1.8109 - learning_rate: 1.0000e-05
# Epoch 122/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4172 - loss: 1.9723 - val_accuracy: 0.4634 - val_loss: 1.8110 - learning_rate: 1.0000e-05
# Epoch 123/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4160 - loss: 1.9604 - val_accuracy: 0.4647 - val_loss: 1.8114 - learning_rate: 1.0000e-05
# Epoch 124/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4097 - loss: 1.9826 - val_accuracy: 0.4657 - val_loss: 1.8105 - learning_rate: 1.0000e-05
# Epoch 125/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4100 - loss: 1.9739 - val_accuracy: 0.4659 - val_loss: 1.8117 - learning_rate: 1.0000e-05
# Epoch 126/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4104 - loss: 1.9815 - val_accuracy: 0.4657 - val_loss: 1.8118 - learning_rate: 1.0000e-05
# Epoch 127/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4138 - loss: 1.9739 - val_accuracy: 0.4644 - val_loss: 1.8112 - learning_rate: 1.0000e-05
# Epoch 128/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4128 - loss: 1.9536 - val_accuracy: 0.4638 - val_loss: 1.8125 - learning_rate: 1.0000e-05
# Epoch 129/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4137 - loss: 1.9632 - val_accuracy: 0.4656 - val_loss: 1.8110 - learning_rate: 1.0000e-05
# Epoch 130/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4142 - loss: 1.9665 - val_accuracy: 0.4647 - val_loss: 1.8117 - learning_rate: 1.0000e-05
# Epoch 131/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4197 - loss: 1.9557 - val_accuracy: 0.4645 - val_loss: 1.8116 - learning_rate: 1.0000e-05
# Epoch 132/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4128 - loss: 1.9599 - val_accuracy: 0.4646 - val_loss: 1.8104 - learning_rate: 1.0000e-05
# Epoch 133/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4123 - loss: 1.9711 - val_accuracy: 0.4649 - val_loss: 1.8106 - learning_rate: 1.0000e-05
# Epoch 134/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4162 - loss: 1.9603 - val_accuracy: 0.4639 - val_loss: 1.8099 - learning_rate: 1.0000e-05
# Epoch 135/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4145 - loss: 1.9692 - val_accuracy: 0.4648 - val_loss: 1.8107 - learning_rate: 1.0000e-05
# Epoch 136/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4190 - loss: 1.9715 - val_accuracy: 0.4649 - val_loss: 1.8116 - learning_rate: 1.0000e-05
# Epoch 137/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4097 - loss: 1.9769 - val_accuracy: 0.4660 - val_loss: 1.8096 - learning_rate: 1.0000e-05
# Epoch 138/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4097 - loss: 1.9809 - val_accuracy: 0.4649 - val_loss: 1.8096 - learning_rate: 1.0000e-05
# Epoch 139/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4219 - loss: 1.9580 - val_accuracy: 0.4643 - val_loss: 1.8111 - learning_rate: 1.0000e-05
# Epoch 140/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4105 - loss: 1.9672 - val_accuracy: 0.4656 - val_loss: 1.8109 - learning_rate: 1.0000e-05
# Epoch 141/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4134 - loss: 1.9770 - val_accuracy: 0.4646 - val_loss: 1.8095 - learning_rate: 1.0000e-05
# Epoch 142/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4148 - loss: 1.9585 - val_accuracy: 0.4653 - val_loss: 1.8101 - learning_rate: 1.0000e-05
# Epoch 143/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4153 - loss: 1.9684 - val_accuracy: 0.4650 - val_loss: 1.8102 - learning_rate: 1.0000e-05
# Epoch 144/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4181 - loss: 1.9695 - val_accuracy: 0.4638 - val_loss: 1.8097 - learning_rate: 1.0000e-05
# Epoch 145/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4104 - loss: 1.9683 - val_accuracy: 0.4646 - val_loss: 1.8099 - learning_rate: 1.0000e-05
# Epoch 146/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4093 - loss: 1.9767 - val_accuracy: 0.4651 - val_loss: 1.8100 - learning_rate: 1.0000e-05
# Epoch 147/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4124 - loss: 1.9691 - val_accuracy: 0.4653 - val_loss: 1.8099 - learning_rate: 1.0000e-05
# Epoch 148/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4129 - loss: 1.9663 - val_accuracy: 0.4645 - val_loss: 1.8098 - learning_rate: 1.0000e-05
# Epoch 149/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4152 - loss: 1.9671 - val_accuracy: 0.4652 - val_loss: 1.8110 - learning_rate: 1.0000e-05
# Epoch 150/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.4154 - loss: 1.9647 - val_accuracy: 0.4645 - val_loss: 1.8090 - learning_rate: 1.0000e-05
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4637 - loss: 1.8183
# [1.8172519207000732, 0.46470001339912415]

# %%
# Compile the model
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0005),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

lr_scheduler = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

history5 = model.fit(train_x, train_y,
                    epochs=150,
                    batch_size = 32,
                    validation_data=(val_x, val_y),
                     callbacks=[early_stopping, lr_scheduler])
plot(history5)
model.evaluate(test_x, test_y)
# Out:
# Epoch 1/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 7ms/step - accuracy: 0.4277 - loss: 1.9862 - val_accuracy: 0.4702 - val_loss: 1.8726 - learning_rate: 5.0000e-04
# Epoch 2/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.4291 - loss: 1.9623 - val_accuracy: 0.4677 - val_loss: 1.8671 - learning_rate: 5.0000e-04
# Epoch 3/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.4332 - loss: 1.9711 - val_accuracy: 0.4531 - val_loss: 1.9167 - learning_rate: 5.0000e-04
# Epoch 4/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.4362 - loss: 1.9700 - val_accuracy: 0.4676 - val_loss: 1.8611 - learning_rate: 5.0000e-04
# Epoch 5/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4397 - loss: 1.9542 - val_accuracy: 0.4644 - val_loss: 1.8912 - learning_rate: 5.0000e-04
# Epoch 6/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4375 - loss: 1.9482 - val_accuracy: 0.4652 - val_loss: 1.8753 - learning_rate: 5.0000e-04
# Epoch 7/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4368 - loss: 1.9656 - val_accuracy: 0.4447 - val_loss: 1.9398 - learning_rate: 5.0000e-04
# Epoch 8/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4529 - loss: 1.9213 - val_accuracy: 0.4694 - val_loss: 1.8456 - learning_rate: 2.5000e-04
# Epoch 9/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4538 - loss: 1.8926 - val_accuracy: 0.4806 - val_loss: 1.8039 - learning_rate: 2.5000e-04
# Epoch 10/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4594 - loss: 1.8824 - val_accuracy: 0.4763 - val_loss: 1.8212 - learning_rate: 2.5000e-04
# Epoch 11/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4616 - loss: 1.8557 - val_accuracy: 0.4832 - val_loss: 1.7986 - learning_rate: 2.5000e-04
# Epoch 12/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.4594 - loss: 1.8682 - val_accuracy: 0.4854 - val_loss: 1.7923 - learning_rate: 2.5000e-04
# Epoch 13/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.4684 - loss: 1.8526 - val_accuracy: 0.4791 - val_loss: 1.8253 - learning_rate: 2.5000e-04
# Epoch 14/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4640 - loss: 1.8540 - val_accuracy: 0.4841 - val_loss: 1.7802 - learning_rate: 2.5000e-04
# Epoch 15/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4652 - loss: 1.8356 - val_accuracy: 0.4881 - val_loss: 1.7810 - learning_rate: 2.5000e-04
# Epoch 16/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4658 - loss: 1.8413 - val_accuracy: 0.4818 - val_loss: 1.7917 - learning_rate: 2.5000e-04
# Epoch 17/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4700 - loss: 1.8353 - val_accuracy: 0.4894 - val_loss: 1.7714 - learning_rate: 2.5000e-04
# Epoch 18/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4669 - loss: 1.8408 - val_accuracy: 0.4814 - val_loss: 1.7994 - learning_rate: 2.5000e-04
# Epoch 19/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.4665 - loss: 1.8399 - val_accuracy: 0.4951 - val_loss: 1.7563 - learning_rate: 2.5000e-04
# Epoch 20/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.4743 - loss: 1.8136 - val_accuracy: 0.4883 - val_loss: 1.7835 - learning_rate: 2.5000e-04
# Epoch 21/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4744 - loss: 1.8229 - val_accuracy: 0.4897 - val_loss: 1.7642 - learning_rate: 2.5000e-04
# Epoch 22/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4676 - loss: 1.8302 - val_accuracy: 0.4906 - val_loss: 1.7706 - learning_rate: 2.5000e-04
# Epoch 23/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4817 - loss: 1.7879 - val_accuracy: 0.5020 - val_loss: 1.7351 - learning_rate: 1.2500e-04
# Epoch 24/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4880 - loss: 1.7670 - val_accuracy: 0.4981 - val_loss: 1.7402 - learning_rate: 1.2500e-04
# Epoch 25/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.4728 - loss: 1.7917 - val_accuracy: 0.4980 - val_loss: 1.7327 - learning_rate: 1.2500e-04
# Epoch 26/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.4831 - loss: 1.7782 - val_accuracy: 0.4981 - val_loss: 1.7318 - learning_rate: 1.2500e-04
# Epoch 27/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4869 - loss: 1.7639 - val_accuracy: 0.4989 - val_loss: 1.7275 - learning_rate: 1.2500e-04
# Epoch 28/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.4887 - loss: 1.7503 - val_accuracy: 0.4994 - val_loss: 1.7335 - learning_rate: 1.2500e-04
# Epoch 29/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.4877 - loss: 1.7620 - val_accuracy: 0.4961 - val_loss: 1.7289 - learning_rate: 1.2500e-04
# Epoch 30/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4914 - loss: 1.7491 - val_accuracy: 0.5044 - val_loss: 1.7167 - learning_rate: 1.2500e-04
# Epoch 31/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4885 - loss: 1.7461 - val_accuracy: 0.5022 - val_loss: 1.7138 - learning_rate: 1.2500e-04
# Epoch 32/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4928 - loss: 1.7364 - val_accuracy: 0.4988 - val_loss: 1.7292 - learning_rate: 1.2500e-04
# Epoch 33/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4850 - loss: 1.7450 - val_accuracy: 0.5045 - val_loss: 1.7119 - learning_rate: 1.2500e-04
# Epoch 34/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4938 - loss: 1.7367 - val_accuracy: 0.4893 - val_loss: 1.7498 - learning_rate: 1.2500e-04
# Epoch 35/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4921 - loss: 1.7481 - val_accuracy: 0.5026 - val_loss: 1.7128 - learning_rate: 1.2500e-04
# Epoch 36/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4930 - loss: 1.7478 - val_accuracy: 0.4984 - val_loss: 1.7223 - learning_rate: 1.2500e-04
# Epoch 37/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4908 - loss: 1.7150 - val_accuracy: 0.5083 - val_loss: 1.6977 - learning_rate: 6.2500e-05
# Epoch 38/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4943 - loss: 1.7231 - val_accuracy: 0.5089 - val_loss: 1.6926 - learning_rate: 6.2500e-05
# Epoch 39/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.4973 - loss: 1.7214 - val_accuracy: 0.5080 - val_loss: 1.6947 - learning_rate: 6.2500e-05
# Epoch 40/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.
150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5092 - loss: 1.6650 - val_accuracy: 0.5131 - val_loss: 1.6709 - learning_rate: 1.0000e-05
# Epoch 64/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5035 - loss: 1.6764 - val_accuracy: 0.5128 - val_loss: 1.6725 - learning_rate: 1.0000e-05
# Epoch 65/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5061 - loss: 1.6791 - val_accuracy: 0.5139 - val_loss: 1.6727 - learning_rate: 1.0000e-05
# Epoch 66/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5085 - loss: 1.6751 - val_accuracy: 0.5136 - val_loss: 1.6717 - learning_rate: 1.0000e-05
# Epoch 67/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5148 - loss: 1.6566 - val_accuracy: 0.5143 - val_loss: 1.6699 - learning_rate: 1.0000e-05
# Epoch 68/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5082 - loss: 1.6710 - val_accuracy: 0.5148 - val_loss: 1.6703 - learning_rate: 1.0000e-05
# Epoch 69/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5072 - loss: 1.6732 - val_accuracy: 0.5140 - val_loss: 1.6698 - learning_rate: 1.0000e-05
# Epoch 70/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5066 - loss: 1.6673 - val_accuracy: 0.5148 - val_loss: 1.6705 - learning_rate: 1.0000e-05
# Epoch 71/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5167 - loss: 1.6583 - val_accuracy: 0.5140 - val_loss: 1.6708 - learning_rate: 1.0000e-05
# Epoch 72/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5121 - loss: 1.6681 - val_accuracy: 0.5140 - val_loss: 1.6694 - learning_rate: 1.0000e-05
# Epoch 73/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5115 - loss: 1.6730 - val_accuracy: 0.5150 - val_loss: 1.6698 - learning_rate: 1.0000e-05
# Epoch 74/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5133 - loss: 1.6644 - val_accuracy: 0.5144 - val_loss: 1.6700 - learning_rate: 1.0000e-05
# Epoch 75/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5069 - loss: 1.6770 - val_accuracy: 0.5125 - val_loss: 1.6693 - learning_rate: 1.0000e-05
# Epoch 76/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5080 - loss: 1.6741 - val_accuracy: 0.5139 - val_loss: 1.6695 - learning_rate: 1.0000e-05
# Epoch 77/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5079 - loss: 1.6631 - val_accuracy: 0.5127 - val_loss: 1.6690 - learning_rate: 1.0000e-05
# Epoch 78/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5111 - loss: 1.6596 - val_accuracy: 0.5131 - val_loss: 1.6701 - learning_rate: 1.0000e-05
# Epoch 79/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5095 - loss: 1.6655 - val_accuracy: 0.5131 - val_loss: 1.6691 - learning_rate: 1.0000e-05
# Epoch 80/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5150 - loss: 1.6567 - val_accuracy: 0.5157 - val_loss: 1.6678 - learning_rate: 1.0000e-05
# Epoch 81/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5114 - loss: 1.6593 - val_accuracy: 0.5150 - val_loss: 1.6680 - learning_rate: 1.0000e-05
# Epoch 82/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5096 - loss: 1.6677 - val_accuracy: 0.5118 - val_loss: 1.6664 - learning_rate: 1.0000e-05
# Epoch 83/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5114 - loss: 1.6684 - val_accuracy: 0.5142 - val_loss: 1.6672 - learning_rate: 1.0000e-05
# Epoch 84/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5143 - loss: 1.6607 - val_accuracy: 0.5137 - val_loss: 1.6661 - learning_rate: 1.0000e-05
# Epoch 85/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5104 - loss: 1.6608 - val_accuracy: 0.5147 - val_loss: 1.6680 - learning_rate: 1.0000e-05
# Epoch 86/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5049 - loss: 1.6638 - val_accuracy: 0.5132 - val_loss: 1.6680 - learning_rate: 1.0000e-05
# Epoch 87/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.
150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5088 - loss: 1.6645 - val_accuracy: 0.5149 - val_loss: 1.6623 - learning_rate: 1.0000e-05
# Epoch 112/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5121 - loss: 1.6565 - val_accuracy: 0.5133 - val_loss: 1.6634 - learning_rate: 1.0000e-05
# Epoch 113/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5110 - loss: 1.6522 - val_accuracy: 0.5163 - val_loss: 1.6608 - learning_rate: 1.0000e-05
# Epoch 114/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5171 - loss: 1.6450 - val_accuracy: 0.5146 - val_loss: 1.6605 - learning_rate: 1.0000e-05
# Epoch 115/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5120 - loss: 1.6416 - val_accuracy: 0.5158 - val_loss: 1.6623 - learning_rate: 1.0000e-05
# Epoch 116/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5111 - loss: 1.6551 - val_accuracy: 0.5135 - val_loss: 1.6611 - learning_rate: 1.0000e-05
# Epoch 117/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5147 - loss: 1.6505 - val_accuracy: 0.5121 - val_loss: 1.6613 - learning_rate: 1.0000e-05
# Epoch 118/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5069 - loss: 1.6572 - val_accuracy: 0.5133 - val_loss: 1.6616 - learning_rate: 1.0000e-05
# Epoch 119/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5176 - loss: 1.6401 - val_accuracy: 0.5143 - val_loss: 1.6606 - learning_rate: 1.0000e-05
# Epoch 120/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5164 - loss: 1.6455 - val_accuracy: 0.5136 - val_loss: 1.6602 - learning_rate: 1.0000e-05
# Epoch 121/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5067 - loss: 1.6593 - val_accuracy: 0.5160 - val_loss: 1.6608 - learning_rate: 1.0000e-05
# Epoch 122/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5093 - loss: 1.6549 - val_accuracy: 0.5131 - val_loss: 1.6600 - learning_rate: 1.0000e-05
# Epoch 123/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5124 - loss: 1.6458 - val_accuracy: 0.5142 - val_loss: 1.6596 - learning_rate: 1.0000e-05
# Epoch 124/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5153 - loss: 1.6419 - val_accuracy: 0.5124 - val_loss: 1.6606 - learning_rate: 1.0000e-05
# Epoch 125/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5149 - loss: 1.6518 - val_accuracy: 0.5151 - val_loss: 1.6599 - learning_rate: 1.0000e-05
# Epoch 126/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5131 - loss: 1.6534 - val_accuracy: 0.5135 - val_loss: 1.6607 - learning_rate: 1.0000e-05
# Epoch 127/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5110 - loss: 1.6530 - val_accuracy: 0.5157 - val_loss: 1.6601 - learning_rate: 1.0000e-05
# Epoch 128/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5120 - loss: 1.6502 - val_accuracy: 0.5121 - val_loss: 1.6607 - learning_rate: 1.0000e-05
# Epoch 129/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5166 - loss: 1.6454 - val_accuracy: 0.5131 - val_loss: 1.6596 - learning_rate: 1.0000e-05
# Epoch 130/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5109 - loss: 1.6593 - val_accuracy: 0.5144 - val_loss: 1.6595 - learning_rate: 1.0000e-05
# Epoch 131/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5112 - loss: 1.6548 - val_accuracy: 0.5146 - val_loss: 1.6576 - learning_rate: 1.0000e-05
# Epoch 132/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5112 - loss: 1.6442 - val_accuracy: 0.5142 - val_loss: 1.6591 - learning_rate: 1.0000e-05
# Epoch 133/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5128 - loss: 1.6485 - val_accuracy: 0.5129 - val_loss: 1.6591 - learning_rate: 1.0000e-05
# Epoch 134/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5097 - loss: 1.6540 - val_accuracy: 0.5124 - val_loss: 1.6583 - learning_rate: 1.0000e-05
# Epoch 135/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5159 - loss: 1.6408 - val_accuracy: 0.5117 - val_loss: 1.6592 - learning_rate: 1.0000e-05
# Epoch 136/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5123 - loss: 1.6486 - val_accuracy: 0.5143 - val_loss: 1.6575 - learning_rate: 1.0000e-05
# Epoch 137/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.5139 - loss: 1.6499 - val_accuracy: 0.5153 - val_loss: 1.6567 - learning_rate: 1.0000e-05
# Epoch 138/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5104 - loss: 1.6528 - val_accuracy: 0.5144 - val_loss: 1.6586 - learning_rate: 1.0000e-05
# Epoch 139/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5167 - loss: 1.6333 - val_accuracy: 0.5144 - val_loss: 1.6583 - learning_rate: 1.0000e-05
# Epoch 140/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5194 - loss: 1.6341 - val_accuracy: 0.5139 - val_loss: 1.6574 - learning_rate: 1.0000e-05
# Epoch 141/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5166 - loss: 1.6334 - val_accuracy: 0.5126 - val_loss: 1.6575 - learning_rate: 1.0000e-05
# Epoch 142/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5089 - loss: 1.6574 - val_accuracy: 0.5160 - val_loss: 1.6571 - learning_rate: 1.0000e-05
# Epoch 143/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5151 - loss: 1.6440 - val_accuracy: 0.5144 - val_loss: 1.6566 - learning_rate: 1.0000e-05
# Epoch 144/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5099 - loss: 1.6555 - val_accuracy: 0.5124 - val_loss: 1.6582 - learning_rate: 1.0000e-05
# Epoch 145/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5160 - loss: 1.6329 - val_accuracy: 0.5132 - val_loss: 1.6575 - learning_rate: 1.0000e-05
# Epoch 146/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5151 - loss: 1.6479 - val_accuracy: 0.5147 - val_loss: 1.6553 - learning_rate: 1.0000e-05
# Epoch 147/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5071 - loss: 1.6583 - val_accuracy: 0.5143 - val_loss: 1.6568 - learning_rate: 1.0000e-05
# Epoch 148/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5165 - loss: 1.6412 - val_accuracy: 0.5139 - val_loss: 1.6561 - learning_rate: 1.0000e-05
# Epoch 149/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5085 - loss: 1.6483 - val_accuracy: 0.5139 - val_loss: 1.6555 - learning_rate: 1.0000e-05
# Epoch 150/150
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.5146 - loss: 1.6370 - val_accuracy: 0.5151 - val_loss: 1.6550 - learning_rate: 1.0000e-05
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5222 - loss: 1.6460
# [1.6469554901123047, 0.5195000171661377]

# %% [markdown]
# #### Xception network

# %%
inputs = keras.Input(shape=(32, 32, 3))


x = layers.RandomFlip("horizontal")(inputs)
x = layers.RandomRotation(0.2)(x)
x = layers.RandomZoom(0.2)(x)


x = layers.Rescaling(1./255)(x)


x = layers.Conv2D(filters=32, kernel_size=5, use_bias=False)(x)


for size in [32, 64, 128, 256, 512]:
    residual = x
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.SeparableConv2D(size, 3, padding="same", use_bias=False)(x)

    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.SeparableConv2D(size, 3, padding="same", use_bias=False)(x)


    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)


    residual = layers.Conv2D(size, 1, strides=2, padding="same", use_bias=False)(residual)
    x = layers.add([x, residual])


x = layers.GlobalAveragePooling2D()(x)

x = layers.Dropout(0.5)(x)

outputs = layers.Dense(20, activation="softmax")(x)


model = keras.Model(inputs=inputs, outputs=outputs)


model.summary()
# Out:
# Model: "functional_158"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_23            │ (None, 32, 32, 3)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ random_flip_3             │ (None, 32, 32, 3)      │              0 │ input_layer_23[0][0]   │
# │ (RandomFlip)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ random_rotation_3         │ (None, 32, 32, 3)      │              0 │ random_flip_3[0][0]    │
# │ (RandomRotation)          │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ random_zoom_3             │ (None, 32, 32, 3)      │              0 │ random_rotation_3[0][… │
# │ (RandomZoom)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rescaling
0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_118 (Conv2D)       │ (None, 1, 1, 512)      │        131,072 │ add_53[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_54 (Add)              │ (None, 1, 1, 512)      │              0 │ max_pooling2d_68[0][0… │
# │                           │                        │                │ conv2d_118[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 512)            │              0 │ add_54[0][0]           │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_53 (Dropout)      │ (None, 512)            │              0 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_38 (Dense)          │ (None, 20)             │         10,260 │ dropout_53[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 731,604 (2.79 MB)
#  Trainable params: 728,596 (2.78 MB)
#  Non-trainable params: 3,008 (11.75 KB)

# %%
# Compile the model
model.compile(
    optimizer=keras.optimizers.RMSprop(),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

lr_scheduler = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)
early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)

history6 = model.fit(train_x, train_y,
                    epochs=100,
                    batch_size = 32,
                    validation_data=(val_x, val_y),
                     callbacks=[early_stopping, lr_scheduler])
plot(history6)
model.evaluate(test_x, test_y)
# Out:
# Epoch 1/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 14ms/step - accuracy: 0.3334 - loss: 2.1551 - val_accuracy: 0.2617 - val_loss: 2.4438 - learning_rate: 0.0010
# Epoch 2/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.3610 - loss: 2.0871 - val_accuracy: 0.0806 - val_loss: 4.9102 - learning_rate: 0.0010
# Epoch 3/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.3634 - loss: 2.0593 - val_accuracy: 0.2321 - val_loss: 2.8133 - learning_rate: 0.0010
# Epoch 4/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.3752 - loss: 2.0137 - val_accuracy: 0.3535 - val_loss: 2.1511 - learning_rate: 0.0010
# Epoch 5/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.3922 - loss: 1.9575 - val_accuracy: 0.3724 - val_loss: 2.0345 - learning_rate: 0.0010
# Epoch 6/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4052 - loss: 1.9291 - val_accuracy: 0.1367 - val_loss: 3.3096 - learning_rate: 0.0010
# Epoch 7/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4120 - loss: 1.9019 - val_accuracy: 0.2857 - val_loss: 2.6534 - learning_rate: 0.0010
# Epoch 8/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4144 - loss: 1.8895 - val_accuracy: 0.4102 - val_loss: 1.8905 - learning_rate: 0.0010
# Epoch 9/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4271 - loss: 1.8470 - val_accuracy: 0.3667 - val_loss: 2.1110 - learning_rate: 0.0010
# Epoch 10/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.4295 - loss: 1.8315 - val_accuracy: 0.3948 - val_loss: 2.0106 - learning_rate: 0.0010
# Epoch 11/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.4442 - loss: 1.8021 - val_accuracy: 0.4152 - val_loss: 1.9745 - learning_rate: 0.0010
# Epoch 12/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4677 - loss: 1.7045 - val_accuracy: 0.3909 - val_loss: 2.0438 - learning_rate: 5.0000e-04
# Epoch 13/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.4766 - loss: 1.6637 - val_accuracy: 0.4606 - val_loss: 1.7596 - learning_rate: 5.0000e-04
# Epoch 14/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4914 - loss: 1.6342 - val_accuracy: 0.4894 - val_loss: 1.6609 - learning_rate: 5.0000e-04
# Epoch 15/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.4999 - loss: 1.6128 - val_accuracy: 0.4209 - val_loss: 1.9394 - learning_rate: 5.0000e-04
# Epoch 16/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5011 - loss: 1.6015 - val_accuracy: 0.4732 - val_loss: 1.7201 - learning_rate: 5.0000e-04
# Epoch 17/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5024 - loss: 1.5799 - val_accuracy: 0.4475 - val_loss: 1.8317 - learning_rate: 5.0000e-04
# Epoch 18/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5164 - loss: 1.5410 - val_accuracy: 0.5044 - val_loss: 1.6041 - learning_rate: 2.5000e-04
# Epoch 19/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5325 - loss: 1.4951 - val_accuracy: 0.5146 - val_loss: 1.5738 - learning_rate: 2.5000e-04
# Epoch 20/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5281 - loss: 1.5094 - val_accuracy: 0.5087 - val_loss: 1.6070 - learning_rate: 2.5000e-04
# Epoch 21/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5389 - loss: 1.4692 - val_accuracy: 0.5043 - val_loss: 1.6182 - learning_rate: 2.5000e-04
# Epoch 22/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5393 - loss: 1.4683 - val_accuracy: 0.5130 - val_loss: 1.5747 - learning_rate: 2.5000e-04
# Epoch 23/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5460 - loss: 1.4514 - val_accuracy: 0.5277 - val_loss: 1.5416 - learning_rate: 1.2500e-04
# Epoch 24/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.5530 - loss: 1.4293 - val_accuracy: 0.5263 - val_loss: 1.5378 - learning_rate: 1.2500e-04
# Epoch 25/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5563 - loss: 1.4212 - val_accuracy: 0.5252 - val_loss: 1.5407 - learning_rate: 1.2500e-04
# Epoch 26/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5552 - loss: 1.4122 - val_accuracy: 0.5286 - val_loss: 1.5259 - learning_rate: 1.2500e-04
# Epoch 27/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.5597 - loss: 1.4078 - val_accuracy: 0.5312 - val_loss: 1.5222 - learning_rate: 1.2500e-04
# Epoch 28/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - accuracy: 0.5580 - loss: 1.4060 - val_accuracy: 0.5246 - val_loss: 1.5642 - learning_rate: 1.2500e-04
# Epoch 29/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.5595 - loss: 1.4058 - val_accuracy: 0.5274 - val_loss: 1.5479 - learning_rate: 1.2500e-04
# Epoch 30/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.5617 - loss: 1.3971 - val_accuracy: 0.5180 - val_loss: 1.5891 - learning_rate: 1.2500e-04
# Epoch 31/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.5685 - loss: 1.3792 - val_accuracy: 0.5338 - val_loss: 1.5141 - learning_rate: 6.2500e-05
# Epoch 32/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - accuracy: 0.5654 - loss: 1.3830 - val_accuracy: 0.5347 - val_loss: 1.5178 - learning_rate: 6.2500e-05
# Epoch 33/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.5743 - loss: 1.3584 - val_accuracy: 0.5376 - val_loss: 1.5121 - learning_rate: 6.2500e-05
# Epoch 34/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - accuracy: 0.5733 - loss: 1.3578 - val_accuracy: 0.5364 - val_loss: 1.5084 - learning_rate: 6.2500e-05
# Epoch 35/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - accuracy: 0.5730 - loss: 1.3550 - val_accuracy: 0.5388 - val_loss: 1.5040 - learning_rate: 6.2500e-05
# Epoch 36/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.5754 - loss: 1.3505 - val_accuracy: 0.5393 - val_loss: 1.5125 - learning_rate: 6.2500e-05
# Epoch 37/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.5771 - loss: 1.3456 - val_accuracy: 0.5366 - val_loss: 1.5132 - learning_rate: 6.2500e-05
# Epoch 38/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5855 - loss: 1.3268 - val_accuracy: 0.5418 - val_loss: 1.4989 - learning_rate: 6.2500e-05
# Epoch 39/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5774 - loss: 1.3577 - val_accuracy: 0.5341 - val_loss: 1.5190 - learning_rate: 6.2500e-05
# Epoch 40/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.5851 - loss: 1.3346 - val_accuracy: 0.5392 - val_loss: 1.5085 - learning_rate: 6.2500e-05
# Epoch 41/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5793 - loss: 1.3432 - val_accuracy: 0.5323 - val_loss: 1.5254 - learning_rate: 6.2500e-05
# Epoch 42/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.5805 - loss: 1.3352 - val_accuracy: 0.5376 - val_loss: 1.5078 - learning_rate: 3.1250e-05
# Epoch 43/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - accuracy: 0.5755 - loss: 1.3363 - val_accuracy: 0.5358 - val_loss: 1.5134 - learning_rate: 3.1250e-05
# Epoch 44/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.5840 - loss: 1.3191 - val_accuracy: 0.5401 - val_loss: 1.4984 - learning_rate: 3.1250e-05
# Epoch 45/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - accuracy: 0.5876 - loss: 1.3199 - val_accuracy: 0.5422 - val_loss: 1.4987 - learning_rate: 3.1250e-05
# Epoch 46/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.5818 - loss: 1.3271 - val_accuracy: 0.5409 - val_loss: 1.5064 - learning_rate: 3.1250e-05
# Epoch 47/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - accuracy: 0.5863 - loss: 1.3191 - val_accuracy: 0.5399 - val_loss: 1.5053 - learning_rate: 3.1250e-05
# Epoch 48/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - accuracy: 0.5841 - loss: 1.3158 - val_accuracy: 0.5452 - val_loss: 1.4928 - learning_rate: 1.5625e-05
# Epoch 49/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.5812 - loss: 1.3221 - val_accuracy: 0.5420 - val_loss: 1.4974 - learning_rate: 1.5625e-05
# Epoch 50/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.5836 - loss: 1.3268 - val_accuracy: 0.5456 - val_loss: 1.4925 - learning_rate: 1.5625e-05
# Epoch 51/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.5902 - loss: 1.3124 - val_accuracy: 0.5439 - val_loss: 1.4982 - learning_rate: 1.5625e-05
# Epoch 52/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 18s 14ms/step - accuracy: 0.5873 - loss: 1.3105 - val_accuracy: 0.5441 - val_loss: 1.4975 - learning_rate: 1.5625e-05
# Epoch 53/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 14ms/step - accuracy: 0.5832 - loss: 1.3291 - val_accuracy: 0.5420 - val_loss: 1.4991 - learning_rate: 1.5625e-05
# Epoch 54/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.5879 - loss: 1.3127 - val_accuracy: 0.5459 - val_loss: 1.4955 - learning_rate: 1.0000e-05
# Epoch 55/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.5901 - loss: 1.3110 - val_accuracy: 0.5441 - val_loss: 1.4969 - learning_rate: 1.0000e-05
# Epoch 56/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.5887 - loss: 1.3091 - val_accuracy: 0.5450 - val_loss: 1.4968 - learning_rate: 1.0000e-05
# Epoch 57/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 17s 13ms/step - accuracy: 0.5847 - loss: 1.3089 - val_accuracy: 0.5467 - val_loss: 1.4937 - learning_rate: 1.0000e-05
# Epoch 58/100
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 16s 13ms/step - accuracy: 0.5880 - loss: 1.3101 - val_accuracy: 0.5460 - val_loss: 1.4937 - learning_rate: 1.0000e-05
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5509 - loss: 1.4853
# [1.4893897771835327, 0.5444999933242798]

# %% [markdown]
# #### Conclusions

# %%
models = [
    "Best CNN Adam",
    "Best CNN RMSProp",
    "Inception Adam",
    "Inception RMSProp",
    "Residual",
    "Xception RMSProp"
]

test_accuracies = [0.6613, 0.6944, 0.5195, 0.46470, 0.6485, 0.5444]


colors = ['royalblue' if 'Adam' in model else 'darkorange' for model in models]


x = np.arange(len(models))
width = 0.5
fig, ax = plt.subplots(figsize=(10, 6))


ax.bar(x, test_accuracies, width, color=colors)


ax.set_xlabel("Models")
ax.set_ylabel("Test Accuracy")
ax.set_title("CIFAR 100 - Model Comparison with Different Optimizers")

ax.set_xticks(x)
ax.set_xticklabels(models, rotation=30, ha="right")

ax.set_ylim(0, 1)

ax.legend()

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-70-b9d839e38d45>:33: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %% [markdown]
# among the architectures, the best CNN performs the best with an accuracy of 0.6613, followed by Residual, which achieves an accuracy of 0.6485. Inception shows lower performance, reaching 0.5195, and Xception achieves an accuracy of 0.5444. The results indicate that the Best CNN and Residual architectures are more effective in this case, while Inception and Xception show relatively lower performance. Although the optimizer plays a role in model performance, these architectures' inherent design and complexity appear to have a more significant impact on the final results.

# %% [markdown]
# ### Helper functions: Plotting and tuning

# %%
import matplotlib.pyplot as plt

def plot(history):
    accuracy = history.history["accuracy"]
    val_accuracy = history.history["val_accuracy"]
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]

    epochs = range(1, len(accuracy) + 1)

    plt.plot(epochs, accuracy, "b-o", label="Training accuracy")
    plt.plot(epochs, val_accuracy, "r--o", label="Validation accuracy")
    plt.title("Training and validation accuracy")
    plt.legend()
    plt.figure()

    plt.plot(epochs, loss, "b-o", label="Training loss")
    plt.plot(epochs, val_loss, "r--o", label="Validation loss")
    plt.title("Training and validation loss")
    plt.legend()

# %%
import keras_tuner as kt

# Function to build the model
def build_model(hp):
    model = keras.Sequential()

    model.add(layers.Conv2D(
        filters=hp.Int('filters_1', min_value=32, max_value=256, step=32),
        kernel_size=hp.Choice('kernel_size_1', values=[3, 5]),
        activation='relu',
        padding='same',
        kernel_regularizer=regularizers.l2(hp.Float('l2_1', 1e-4, 1e-2, sampling='log')),
        input_shape=(32, 32, 3)
    ))
    model.add(layers.BatchNormalization())

    # Number of Conv Layers (3, 5, or 6)
    for i in range(hp.Choice('num_conv_layers', [3, 5, 6])):
        model.add(layers.Conv2D(
            filters=hp.Int(f'filters_{i+2}', min_value=32, max_value=256, step=32),
            kernel_size=hp.Choice(f'kernel_size_{i+2}', values=[3, 5]),
            activation='relu',
            padding='same',
            kernel_regularizer=regularizers.l2(hp.Float(f'l2_{i+2}', 1e-4, 1e-2, sampling='log'))
        ))
        model.add(layers.BatchNormalization())

        # Apply MaxPooling only if dimensions allow it
        if model.output_shape[1] > 2 and model.output_shape[2] > 2:
            model.add(layers.MaxPooling2D((2, 2)))

        model.add(layers.Dropout(rate=hp.Float(f'dropout_{i+2}', 0.2, 0.5, step=0.1)))

    model.add(layers.Flatten())

    # We add dense Layers for generalization
    for j in range(hp.Int('num_dense_layers', 1, 3)):  # 1 to 3 dense layers aprox
        model.add(layers.Dense(
            units=hp.Int(f'dense_units_{j+1}', min_value=128, max_value=512, step=128),
            activation='relu',
            kernel_regularizer=regularizers.l2(hp.Float(f'l2_dense_{j+1}', 1e-4, 1e-2, sampling='log'))
        ))
        model.add(layers.Dropout(rate=hp.Float(f'dense_dropout_{j+1}', 0.2, 0.5, step=0.1)))

    model.add(layers.Dense(20, activation='softmax'))

    # Optimizer and learning rate (we will do manual tests also)
    optimizer = hp.Choice('optimizer', ['adam', 'sgd', 'rmsprop'])
    learning_rate = hp.Float('learning_rate', 1e-4, 1e-2, sampling='log')

    model.compile(
        optimizer=keras.optimizers.get({"class_name": optimizer, "config": {"learning_rate": learning_rate}}),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model

# Define keras tuner
tuner = kt.Hyperband(
    build_model,
    objective="val_accuracy",
    max_epochs=20,
    factor=3,
    directory="hyperband_tuning",
    project_name="cnn_tuning"
)


# Train model with early stopping because of overfitting
early_stopping = keras.callbacks.EarlyStopping(monitor="val_loss", patience=3, restore_best_weights=True)

tuner.search(train_x, train_y, validation_data=(val_x, val_y), epochs=20, callbacks=[early_stopping])

# Get the best model
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
best_model = tuner.get_best_models(num_models=1)[0]

# Save the best model
best_model.save("best_model.h5")
